# %%
import requests
#環保署環境資料開放平台開放資料API,酸雨資料,每日,有自已的id,要到環保署登入申請

url="https://data.epa.gov.tw/api/v1/acidr_p_01?format=json&offset=0&limit=1000&api_key=84a024b0-1d85-460c-b330-d96b9ea12cb9"

# %%
response = requests.get(url)
response.__class__
# Out:
# requests.models.Response

# %%
response.json()
# Out:
# {'sort': 'ImportDate desc',
#  'include_total': True,
#  'resource_id': '103c62f6-0e7a-4d71-9c11-b38dac783e01',
#  'fields': [{'info': {'notes': '3', 'label': '測站代碼'},
#    'type': 'text',
#    'id': 'SiteId'},
#   {'info': {'notes': '萬里', 'label': '測站中文名稱'},
#    'type': 'text',
#    'id': 'Site_Name'},
#   {'info': {'notes': 'Wanli', 'label': '測站英文名稱'},
#    'type': 'text',
#    'id': 'Site_EName'},
#   {'info': {'notes': '北部空品區', 'label': '測站區域'}, 'type': 'text', 'id': 'Area'},
#   {'info': {'notes': '新北市', 'label': '縣市名稱'}, 'type': 'text', 'id': 'County'},
#   {'info': {'notes': '萬里區', 'label': '鄉鎮名稱'},
#    'type': 'text',
#    'id': 'Township'},
#   {'info': {'notes': '新北市萬里區瑪鋉路221號', 'label': '測站地址'},
#    'type': 'text',
#    'id': 'Site_Address'},
#   {'info': {'notes': '121.689881', 'label': '測站經度'},
#    'type': 'text',
#    'id': 'Longitude'},
#   {'info': {'notes': '25.179667', 'label': '測站緯度'},
#    'type': 'text',
#    'id': 'Latitude'},
#   {'info': {'notes': '行政院環境保護署', 'label': '管理機關名稱'},
#    'type': 'text',
#    'id': 'Agency_Name'},
#   {'info': {'notes': '201312', 'label': '監測月份'},
#    'type': 'text',
#    'id': 'Monitor_Month'},
#   {'info': {'notes': '20131217', 'label': '監測日期'},
#    'type': 'text',
#    'id': 'Monitor_Date'},
#   {'info': {'notes': '酸雨pH值', 'label': '測項名稱'},
#    'type': 'text',
#    'id': 'Item_Name'},
#   {'info': {'notes': 'PH_RAIN', 'label': '測項英文名稱'},
#    'type': 'text',
#    'id': 'Item_EName'},
#   {'info': {'notes': '4.99', 'label': '監測值'},
#    'type': 'text',
#    'id': 'Result_Value'},
#   {'info': {'notes': '', 'label': '測項單位'}, 'type': 'text', 'id': 'Item_Unit'}],
#  '__extras': {'api_key': '84a024b0-1d85-460c-b330-d96b9ea12cb9'},
#  'records_format': 'objects',
#  'records': [{'SiteId': '78',
#    'Site_Name': '馬公',
#    'Site_EName': 'Magong',
#    'Area': '其他',
#    'County': '澎湖縣',
#    'Township': '馬公市',
#    'Site_Address': '澎湖縣馬公市中正路115號',
#    'Longitude': '119.566158',
#    'Latitude': '23.569031',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '3',
#    'Site_Name': '萬里',
#    'Site_EName': 'Wanli',
#    'Area': '北部空品區',
#    'County': '新北市',
#    'Township': '萬里區',
#    'Site_Address': '新北市萬里區瑪鋉路221號',
#    'Longitude': '121.689881',
#    'Latitude': '25.179667',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '12',
#    'Item_Unit': 'mm'},
#   {'SiteId': '6',
#    'Site_Name': '板橋',
#    'Site_EName': 'Banqiao',
#    'Area': '北部空品區',
#    'County': '新北市',
#    'Township': '板橋區',
#    'Site_Address': '新北市板橋區文化路一段25號',
#    'Longitude': '121.458667',
#    'Latitude': '25.012972',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '19',
#    'Site_Name': '觀音',
#    'Site_EName': 'Guanyin',
#    'Area': '北部空品區',
#    'County': '桃園市',
#    'Township': '觀音區',
#    'Site_Address': '桃園市觀音區文化路2號',
#    'Longitude': '121.082761',
#    'Latitude': '25.035503',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '27',
#    'Site_Name': '三義',
#    'Site_EName': 'Sanyi',
#    'Area': '竹苗空品區',
#    'County': '苗栗縣',
#    'Township': '三義鄉',
#    'Site_Address': '苗栗縣三義鄉西湖村上湖61-1號',
#    'Longitude': '120.758833',
#    'Latitude': '24.382942',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '32',
#    'Site_Name': '西屯',
#    'Site_EName': 'Xitun',
#    'Area': '中部空品區',
#    'County': '臺中市',
#    'Township': '西屯區',
#    'Site_Address': '臺中市西屯區安和路1號',
#    'Longitude': '120.616917',
#    'Latitude': '24.162197',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '36',
#    'Site_Name': '南投',
#    'Site_EName': 'Nantou',
#    'Area': '中部空品區',
#    'County': '南投縣',
#    'Township': '南投市',
#    'Site_Address': '南投市南陽路269號',
#    'Longitude': '120.685306',
#    'Latitude': '23.913',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '38',
#    'Site_Name': '崙背',
#    'Site_EName': 'Lunbei',
#    'Area': '雲嘉南空品區',
#    'County': '雲林縣',
#    'Township': '崙背鄉',
#    'Site_Address': '雲林縣崙背鄉南陽村大成路91號',
#    'Longitude': '120.348742',
#    'Latitude': '23.757547',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '43',
#    'Site_Name': '新營',
#    'Site_EName': 'Xinying',
#    'Area': '雲嘉南空品區',
#    'County': '臺南市',
#    'Township': '新營區',
#    'Site_Address': '臺南市新營區中正路4號',
#    'Longitude': '120.31725',
#    'Latitude': '23.305633',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '48',
#    'Site_Name': '橋頭',
#    'Site_EName': 'Qiaotou',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '橋頭區',
#    'Site_Address': '高雄市橋頭區隆豐北路1號',
#    'Longitude': '120.305689',
#    'Latitude': '22.757506',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '50',
#    'Site_Name': '鳳山',
#    'Site_EName': 'Fengshan',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '鳳山區',
#    'Site_Address': '高雄市鳳山區曹公路6號',
#    'Longitude': '120.358083',
#    'Latitude': '22.627392',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '58',
#    'Site_Name': '小港',
#    'Site_EName': 'Xiaogang',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '小港區',
#    'Site_Address': '高雄市小港區平和南路185號',
#    'Longitude': '120.337736',
#    'Latitude': '22.565833',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '61',
#    'Site_Name': '恆春',
#    'Site_EName': 'Hengchun',
#    'Area': '高屏空品區',
#    'County': '屏東縣',
#    'Township': '恆春鎮',
#    'Site_Address': '屏東縣恆春鎮公園路44號',
#    'Longitude': '120.788928',
#    'Latitude': '21.958069',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '62',
#    'Site_Name': '臺東',
#    'Site_EName': 'Taitung',
#    'Area': '花東空品區',
#    'County': '臺東縣',
#    'Township': '台東市',
#    'Site_Address': '臺東市中山路276號',
#    'Longitude': '121.15045',
#    'Latitude': '22.755358',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0.5',
#    'Item_Unit': 'mm'},
#   {'SiteId': '63',
#    'Site_Name': '花蓮',
#    'Site_EName': 'Hualien',
#    'Area': '花東空品區',
#    'County': '花蓮縣',
#    'Township': '花蓮市',
#    'Site_Address': '花蓮市中正路210號',
#    'Longitude': '121.599769',
#    'Latitude': '23.971306',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '21.5',
#    'Item_Unit': 'mm'},
#   {'SiteId': '64',
#    'Site_Name': '陽明',
#    'Site_EName': 'Yangming',
#    'Area': '北部空品區',
#    'County': '臺北市',
#    'Township': '北投區',
#    'Site_Address': '臺北市北投區竹子湖路111號',
#    'Longitude': '121.529583',
#    'Latitude': '25.182722',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '1.5',
#    'Item_Unit': 'mm'},
#   {'SiteId': '66',
#    'Site_Name': '冬山',
#    'Site_EName': 'Dongshan',
#    'Area': '宜蘭空品區',
#    'County': '宜蘭縣',
#    'Township': '冬山鄉',
#    'Site_Address': '宜蘭縣冬山鄉南興村照安路26號',
#    'Longitude': '121.792928',
#    'Latitude': '24.632203',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '8',
#    'Item_Unit': 'mm'},
#   {'SiteId': '75',
#    'Site_Name': '馬祖',
#    'Site_EName': 'Matsu',
#    'Area': '其他',
#    'County': '連江縣',
#    'Township': '南竿鄉',
#    'Site_Address': '連江縣南竿鄉介壽村13號',
#    'Longitude': '119.949875',
#    'Latitude': '26.160469',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '77',
#    'Site_Name': '金門',
#    'Site_EName': 'Kinmen',
#    'Area': '其他',
#    'County': '金門縣',
#    'Township': '金城鎮',
#    'Site_Address': '金門縣金城鎮民權路32號',
#    'Longitude': '118.312256',
#    'Latitude': '24.432133',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220104',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '50',
#    'Site_Name': '鳳山',
#    'Site_EName': 'Fengshan',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '鳳山區',
#    'Site_Address': '高雄市鳳山區曹公路6號',
#    'Longitude': '120.358083',
#    'Latitude': '22.627392',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '3',
#    'Site_Name': '萬里',
#    'Site_EName': 'Wanli',
#    'Area': '北部空品區',
#    'County': '新北市',
#    'Township': '萬里區',
#    'Site_Address': '新北市萬里區瑪鋉路221號',
#    'Longitude': '121.689881',
#    'Latitude': '25.179667',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '6',
#    'Site_Name': '板橋',
#    'Site_EName': 'Banqiao',
#    'Area': '北部空品區',
#    'County': '新北市',
#    'Township': '板橋區',
#    'Site_Address': '新北市板橋區文化路一段25號',
#    'Longitude': '121.458667',
#    'Latitude': '25.012972',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '19',
#    'Site_Name': '觀音',
#    'Site_EName': 'Guanyin',
#    'Area': '北部空品區',
#    'County': '桃園市',
#    'Township': '觀音區',
#    'Site_Address': '桃園市觀音區文化路2號',
#    'Longitude': '121.082761',
#    'Latitude': '25.035503',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '27',
#    'Site_Name': '三義',
#    'Site_EName': 'Sanyi',
#    'Area': '竹苗空品區',
#    'County': '苗栗縣',
#    'Township': '三義鄉',
#    'Site_Address': '苗栗縣三義鄉西湖村上湖61-1號',
#    'Longitude': '120.758833',
#    'Latitude': '24.382942',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '32',
#    'Site_Name': '西屯',
#    'Site_EName': 'Xitun',
#    'Area': '中部空品區',
#    'County': '臺中市',
#    'Township': '西屯區',
#    'Site_Address': '臺中市西屯區安和路1號',
#    'Longitude': '120.616917',
#    'Latitude': '24.162197',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '36',
#    'Site_Name': '南投',
#    'Site_EName': 'Nantou',
#    'Area': '中部空品區',
#    'County': '南投縣',
#    'Township': '南投市',
#    'Site_Address': '南投市南陽路269號',
#    'Longitude': '120.685306',
#    'Latitude': '23.913',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '38',
#    'Site_Name': '崙背',
#    'Site_EName': 'Lunbei',
#    'Area': '雲嘉南空品區',
#    'County': '雲林縣',
#    'Township': '崙背鄉',
#    'Site_Address': '雲林縣崙背鄉南陽村大成路91號',
#    'Longitude': '120.348742',
#    'Latitude': '23.757547',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '43',
#    'Site_Name': '新營',
#    'Site_EName': 'Xinying',
#    'Area': '雲嘉南空品區',
#    'County': '臺南市',
#    'Township': '新營區',
#    'Site_Address': '臺南市新營區中正路4號',
#    'Longitude': '120.31725',
#    'Latitude': '23.305633',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '78',
#    'Site_Name': '馬公',
#    'Site_EName': 'Magong',
#    'Area': '其他',
#    'County': '澎湖縣',
#    'Township': '馬公市',
#    'Site_Address': '澎湖縣馬公市中正路115號',
#    'Longitude': '119.566158',
#    'Latitude': '23.569031',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '77',
#    'Site_Name': '金門',
#    'Site_EName': 'Kinmen',
#    'Area': '其他',
#    'County': '金門縣',
#    'Township': '金城鎮',
#    'Site_Address': '金門縣金城鎮民權路32號',
#    'Longitude': '118.312256',
#    'Latitude': '24.432133',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '75',
#    'Site_Name': '馬祖',
#    'Site_EName': 'Matsu',
#    'Area': '其他',
#    'County': '連江縣',
#    'Township': '南竿鄉',
#    'Site_Address': '連江縣南竿鄉介壽村13號',
#    'Longitude': '119.949875',
#    'Latitude': '26.160469',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '66',
#    'Site_Name': '冬山',
#    'Site_EName': 'Dongshan',
#    'Area': '宜蘭空品區',
#    'County': '宜蘭縣',
#    'Township': '冬山鄉',
#    'Site_Address': '宜蘭縣冬山鄉南興村照安路26號',
#    'Longitude': '121.792928',
#    'Latitude': '24.632203',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '64',
#    'Site_Name': '陽明',
#    'Site_EName': 'Yangming',
#    'Area': '北部空品區',
#    'County': '臺北市',
#    'Township': '北投區',
#    'Site_Address': '臺北市北投區竹子湖路111號',
#    'Longitude': '121.529583',
#    'Latitude': '25.182722',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '63',
#    'Site_Name': '花蓮',
#    'Site_EName': 'Hualien',
#    'Area': '花東空品區',
#    'County': '花蓮縣',
#    'Township': '花蓮市',
#    'Site_Address': '花蓮市中正路210號',
#    'Longitude': '121.599769',
#    'Latitude': '23.971306',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '62',
#    'Site_Name': '臺東',
#    'Site_EName': 'Taitung',
#    'Area': '花東空品區',
#    'County': '臺東縣',
#    'Township': '台東市',
#    'Site_Address': '臺東市中山路276號',
#    'Longitude': '121.15045',
#    'Latitude': '22.755358',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '61',
#    'Site_Name': '恆春',
#    'Site_EName': 'Hengchun',
#    'Area': '高屏空品區',
#    'County': '屏東縣',
#    'Township': '恆春鎮',
#    'Site_Address': '屏東縣恆春鎮公園路44號',
#    'Longitude': '120.788928',
#    'Latitude': '21.958069',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '58',
#    'Site_Name': '小港',
#    'Site_EName': 'Xiaogang',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '小港區',
#    'Site_Address': '高雄市小港區平和南路185號',
#    'Longitude': '120.337736',
#    'Latitude': '22.565833',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '48',
#    'Site_Name': '橋頭',
#    'Site_EName': 'Qiaotou',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '橋頭區',
#    'Site_Address': '高雄市橋頭區隆豐北路1號',
#    'Longitude': '120.305689',
#    'Latitude': '22.757506',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220103',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '6',
#    'Site_Name': '板橋',
#    'Site_EName': 'Banqiao',
#    'Area': '北部空品區',
#    'County': '新北市',
#    'Township': '板橋區',
#    'Site_Address': '新北市板橋區文化路一段25號',
#    'Longitude': '121.458667',
#    'Latitude': '25.012972',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '3',
#    'Site_Name': '萬里',
#    'Site_EName': 'Wanli',
#    'Area': '北部空品區',
#    'County': '新北市',
#    'Township': '萬里區',
#    'Site_Address': '新北市萬里區瑪鋉路221號',
#    'Longitude': '121.689881',
#    'Latitude': '25.179667',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '78',
#    'Site_Name': '馬公',
#    'Site_EName': 'Magong',
#    'Area': '其他',
#    'County': '澎湖縣',
#    'Township': '馬公市',
#    'Site_Address': '澎湖縣馬公市中正路115號',
#    'Longitude': '119.566158',
#    'Latitude': '23.569031',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '77',
#    'Site_Name': '金門',
#    'Site_EName': 'Kinmen',
#    'Area': '其他',
#    'County': '金門縣',
#    'Township': '金城鎮',
#    'Site_Address': '金門縣金城鎮民權路32號',
#    'Longitude': '118.312256',
#    'Latitude': '24.432133',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '75',
#    'Site_Name': '馬祖',
#    'Site_EName': 'Matsu',
#    'Area': '其他',
#    'County': '連江縣',
#    'Township': '南竿鄉',
#    'Site_Address': '連江縣南竿鄉介壽村13號',
#    'Longitude': '119.949875',
#    'Latitude': '26.160469',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '66',
#    'Site_Name': '冬山',
#    'Site_EName': 'Dongshan',
#    'Area': '宜蘭空品區',
#    'County': '宜蘭縣',
#    'Township': '冬山鄉',
#    'Site_Address': '宜蘭縣冬山鄉南興村照安路26號',
#    'Longitude': '121.792928',
#    'Latitude': '24.632203',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '64',
#    'Site_Name': '陽明',
#    'Site_EName': 'Yangming',
#    'Area': '北部空品區',
#    'County': '臺北市',
#    'Township': '北投區',
#    'Site_Address': '臺北市北投區竹子湖路111號',
#    'Longitude': '121.529583',
#    'Latitude': '25.182722',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0.5',
#    'Item_Unit': 'mm'},
#   {'SiteId': '63',
#    'Site_Name': '花蓮',
#    'Site_EName': 'Hualien',
#    'Area': '花東空品區',
#    'County': '花蓮縣',
#    'Township': '花蓮市',
#    'Site_Address': '花蓮市中正路210號',
#    'Longitude': '121.599769',
#    'Latitude': '23.971306',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0.5',
#    'Item_Unit': 'mm'},
#   {'SiteId': '62',
#    'Site_Name': '臺東',
#    'Site_EName': 'Taitung',
#    'Area': '花東空品區',
#    'County': '臺東縣',
#    'Township': '台東市',
#    'Site_Address': '臺東市中山路276號',
#    'Longitude': '121.15045',
#    'Latitude': '22.755358',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '61',
#    'Site_Name': '恆春',
#    'Site_EName': 'Hengchun',
#    'Area': '高屏空品區',
#    'County': '屏東縣',
#    'Township': '恆春鎮',
#    'Site_Address': '屏東縣恆春鎮公園路44號',
#    'Longitude': '120.788928',
#    'Latitude': '21.958069',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '58',
#    'Site_Name': '小港',
#    'Site_EName': 'Xiaogang',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '小港區',
#    'Site_Address': '高雄市小港區平和南路185號',
#    'Longitude': '120.337736',
#    'Latitude': '22.565833',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '50',
#    'Site_Name': '鳳山',
#    'Site_EName': 'Fengshan',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '鳳山區',
#    'Site_Address': '高雄市鳳山區曹公路6號',
#    'Longitude': '120.358083',
#    'Latitude': '22.627392',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '48',
#    'Site_Name': '橋頭',
#    'Site_EName': 'Qiaotou',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '橋頭區',
#    'Site_Address': '高雄市橋頭區隆豐北路1號',
#    'Longitude': '120.305689',
#    'Latitude': '22.757506',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '43',
#    'Site_Name': '新營',
#    'Site_EName': 'Xinying',
#    'Area': '雲嘉南空品區',
#    'County': '臺南市',
#    'Township': '新營區',
#    'Site_Address': '臺南市新營區中正路4號',
#    'Longitude': '120.31725',
#    'Latitude': '23.305633',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '38',
#    'Site_Name': '崙背',
#    'Site_EName': 'Lunbei',
#    'Area': '雲嘉南空品區',
#    'County': '雲林縣',
#    'Township': '崙背鄉',
#    'Site_Address': '雲林縣崙背鄉南陽村大成路91號',
#    'Longitude': '120.348742',
#    'Latitude': '23.757547',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '36',
#    'Site_Name': '南投',
#    'Site_EName': 'Nantou',
#    'Area': '中部空品區',
#    'County': '南投縣',
#    'Township': '南投市',
#    'Site_Address': '南投市南陽路269號',
#    'Longitude': '120.685306',
#    'Latitude': '23.913',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '32',
#    'Site_Name': '西屯',
#    'Site_EName': 'Xitun',
#    'Area': '中部空品區',
#    'County': '臺中市',
#    'Township': '西屯區',
#    'Site_Address': '臺中市西屯區安和路1號',
#    'Longitude': '120.616917',
#    'Latitude': '24.162197',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '27',
#    'Site_Name': '三義',
#    'Site_EName': 'Sanyi',
#    'Area': '竹苗空品區',
#    'County': '苗栗縣',
#    'Township': '三義鄉',
#    'Site_Address': '苗栗縣三義鄉西湖村上湖61-1號',
#    'Longitude': '120.758833',
#    'Latitude': '24.382942',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '19',
#    'Site_Name': '觀音',
#    'Site_EName': 'Guanyin',
#    'Area': '北部空品區',
#    'County': '桃園市',
#    'Township': '觀音區',
#    'Site_Address': '桃園市觀音區文化路2號',
#    'Longitude': '121.082761',
#    'Latitude': '25.035503',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220102',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '63',
#    'Site_Name': '花蓮',
#    'Site_EName': 'Hualien',
#    'Area': '花東空品區',
#    'County': '花蓮縣',
#    'Township': '花蓮市',
#    'Site_Address': '花蓮市中正路210號',
#    'Longitude': '121.599769',
#    'Latitude': '23.971306',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '1.5',
#    'Item_Unit': 'mm'},
#   {'SiteId': '78',
#    'Site_Name': '馬公',
#    'Site_EName': 'Magong',
#    'Area': '其他',
#    'County': '澎湖縣',
#    'Township': '馬公市',
#    'Site_Address': '澎湖縣馬公市中正路115號',
#    'Longitude': '119.566158',
#    'Latitude': '23.569031',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '77',
#    'Site_Name': '金門',
#    'Site_EName': 'Kinmen',
#    'Area': '其他',
#    'County': '金門縣',
#    'Township': '金城鎮',
#    'Site_Address': '金門縣金城鎮民權路32號',
#    'Longitude': '118.312256',
#    'Latitude': '24.432133',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '75',
#    'Site_Name': '馬祖',
#    'Site_EName': 'Matsu',
#    'Area': '其他',
#    'County': '連江縣',
#    'Township': '南竿鄉',
#    'Site_Address': '連江縣南竿鄉介壽村13號',
#    'Longitude': '119.949875',
#    'Latitude': '26.160469',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '66',
#    'Site_Name': '冬山',
#    'Site_EName': 'Dongshan',
#    'Area': '宜蘭空品區',
#    'County': '宜蘭縣',
#    'Township': '冬山鄉',
#    'Site_Address': '宜蘭縣冬山鄉南興村照安路26號',
#    'Longitude': '121.792928',
#    'Latitude': '24.632203',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '3',
#    'Item_Unit': 'mm'},
#   {'SiteId': '64',
#    'Site_Name': '陽明',
#    'Site_EName': 'Yangming',
#    'Area': '北部空品區',
#    'County': '臺北市',
#    'Township': '北投區',
#    'Site_Address': '臺北市北投區竹子湖路111號',
#    'Longitude': '121.529583',
#    'Latitude': '25.182722',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '1.5',
#    'Item_Unit': 'mm'},
#   {'SiteId': '62',
#    'Site_Name': '臺東',
#    'Site_EName': 'Taitung',
#    'Area': '花東空品區',
#    'County': '臺東縣',
#    'Township': '台東市',
#    'Site_Address': '臺東市中山路276號',
#    'Longitude': '121.15045',
#    'Latitude': '22.755358',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '61',
#    'Site_Name': '恆春',
#    'Site_EName': 'Hengchun',
#    'Area': '高屏空品區',
#    'County': '屏東縣',
#    'Township': '恆春鎮',
#    'Site_Address': '屏東縣恆春鎮公園路44號',
#    'Longitude': '120.788928',
#    'Latitude': '21.958069',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '58',
#    'Site_Name': '小港',
#    'Site_EName': 'Xiaogang',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '小港區',
#    'Site_Address': '高雄市小港區平和南路185號',
#    'Longitude': '120.337736',
#    'Latitude': '22.565833',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '50',
#    'Site_Name': '鳳山',
#    'Site_EName': 'Fengshan',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '鳳山區',
#    'Site_Address': '高雄市鳳山區曹公路6號',
#    'Longitude': '120.358083',
#    'Latitude': '22.627392',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '48',
#    'Site_Name': '橋頭',
#    'Site_EName': 'Qiaotou',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '橋頭區',
#    'Site_Address': '高雄市橋頭區隆豐北路1號',
#    'Longitude': '120.305689',
#    'Latitude': '22.757506',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '43',
#    'Site_Name': '新營',
#    'Site_EName': 'Xinying',
#    'Area': '雲嘉南空品區',
#    'County': '臺南市',
#    'Township': '新營區',
#    'Site_Address': '臺南市新營區中正路4號',
#    'Longitude': '120.31725',
#    'Latitude': '23.305633',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '38',
#    'Site_Name': '崙背',
#    'Site_EName': 'Lunbei',
#    'Area': '雲嘉南空品區',
#    'County': '雲林縣',
#    'Township': '崙背鄉',
#    'Site_Address': '雲林縣崙背鄉南陽村大成路91號',
#    'Longitude': '120.348742',
#    'Latitude': '23.757547',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '36',
#    'Site_Name': '南投',
#    'Site_EName': 'Nantou',
#    'Area': '中部空品區',
#    'County': '南投縣',
#    'Township': '南投市',
#    'Site_Address': '南投市南陽路269號',
#    'Longitude': '120.685306',
#    'Latitude': '23.913',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '32',
#    'Site_Name': '西屯',
#    'Site_EName': 'Xitun',
#    'Area': '中部空品區',
#    'County': '臺中市',
#    'Township': '西屯區',
#    'Site_Address': '臺中市西屯區安和路1號',
#    'Longitude': '120.616917',
#    'Latitude': '24.162197',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '27',
#    'Site_Name': '三義',
#    'Site_EName': 'Sanyi',
#    'Area': '竹苗空品區',
#    'County': '苗栗縣',
#    'Township': '三義鄉',
#    'Site_Address': '苗栗縣三義鄉西湖村上湖61-1號',
#    'Longitude': '120.758833',
#    'Latitude': '24.382942',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '19',
#    'Site_Name': '觀音',
#    'Site_EName': 'Guanyin',
#    'Area': '北部空品區',
#    'County': '桃園市',
#    'Township': '觀音區',
#    'Site_Address': '桃園市觀音區文化路2號',
#    'Longitude': '121.082761',
#    'Latitude': '25.035503',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '3',
#    'Site_Name': '萬里',
#    'Site_EName': 'Wanli',
#    'Area': '北部空品區',
#    'County': '新北市',
#    'Township': '萬里區',
#    'Site_Address': '新北市萬里區瑪鋉路221號',
#    'Longitude': '121.689881',
#    'Latitude': '25.179667',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '1',
#    'Item_Unit': 'mm'},
#   {'SiteId': '6',
#    'Site_Name': '板橋',
#    'Site_EName': 'Banqiao',
#    'Area': '北部空品區',
#    'County': '新北市',
#    'Township': '板橋區',
#    'Site_Address': '新北市板橋區文化路一段25號',
#    'Longitude': '121.458667',
#    'Latitude': '25.012972',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202201',
#    'Monitor_Date': '20220101',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '58',
#    'Site_Name': '小港',
#    'Site_EName': 'Xiaogang',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '小港區',
#    'Site_Address': '高雄市小港區平和南路185號',
#    'Longitude': '120.337736',
#    'Latitude': '22.565833',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '61',
#    'Site_Name': '恆春',
#    'Site_EName': 'Hengchun',
#    'Area': '高屏空品區',
#    'County': '屏東縣',
#    'Township': '恆春鎮',
#    'Site_Address': '屏東縣恆春鎮公園路44號',
#    'Longitude': '120.788928',
#    'Latitude': '21.958069',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '62',
#    'Site_Name': '臺東',
#    'Site_EName': 'Taitung',
#    'Area': '花東空品區',
#    'County': '臺東縣',
#    'Township': '台東市',
#    'Site_Address': '臺東市中山路276號',
#    'Longitude': '121.15045',
#    'Latitude': '22.755358',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '63',
#    'Site_Name': '花蓮',
#    'Site_EName': 'Hualien',
#    'Area': '花東空品區',
#    'County': '花蓮縣',
#    'Township': '花蓮市',
#    'Site_Address': '花蓮市中正路210號',
#    'Longitude': '121.599769',
#    'Latitude': '23.971306',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '64',
#    'Site_Name': '陽明',
#    'Site_EName': 'Yangming',
#    'Area': '北部空品區',
#    'County': '臺北市',
#    'Township': '北投區',
#    'Site_Address': '臺北市北投區竹子湖路111號',
#    'Longitude': '121.529583',
#    'Latitude': '25.182722',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '3',
#    'Item_Unit': 'mm'},
#   {'SiteId': '66',
#    'Site_Name': '冬山',
#    'Site_EName': 'Dongshan',
#    'Area': '宜蘭空品區',
#    'County': '宜蘭縣',
#    'Township': '冬山鄉',
#    'Site_Address': '宜蘭縣冬山鄉南興村照安路26號',
#    'Longitude': '121.792928',
#    'Latitude': '24.632203',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '4.5',
#    'Item_Unit': 'mm'},
#   {'SiteId': '77',
#    'Site_Name': '金門',
#    'Site_EName': 'Kinmen',
#    'Area': '其他',
#    'County': '金門縣',
#    'Township': '金城鎮',
#    'Site_Address': '金門縣金城鎮民權路32號',
#    'Longitude': '118.312256',
#    'Latitude': '24.432133',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '75',
#    'Site_Name': '馬祖',
#    'Site_EName': 'Matsu',
#    'Area': '其他',
#    'County': '連江縣',
#    'Township': '南竿鄉',
#    'Site_Address': '連江縣南竿鄉介壽村13號',
#    'Longitude': '119.949875',
#    'Latitude': '26.160469',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '3',
#    'Site_Name': '萬里',
#    'Site_EName': 'Wanli',
#    'Area': '北部空品區',
#    'County': '新北市',
#    'Township': '萬里區',
#    'Site_Address': '新北市萬里區瑪鋉路221號',
#    'Longitude': '121.689881',
#    'Latitude': '25.179667',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '3',
#    'Item_Unit': 'mm'},
#   {'SiteId': '6',
#    'Site_Name': '板橋',
#    'Site_EName': 'Banqiao',
#    'Area': '北部空品區',
#    'County': '新北市',
#    'Township': '板橋區',
#    'Site_Address': '新北市板橋區文化路一段25號',
#    'Longitude': '121.458667',
#    'Latitude': '25.012972',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '19',
#    'Site_Name': '觀音',
#    'Site_EName': 'Guanyin',
#    'Area': '北部空品區',
#    'County': '桃園市',
#    'Township': '觀音區',
#    'Site_Address': '桃園市觀音區文化路2號',
#    'Longitude': '121.082761',
#    'Latitude': '25.035503',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '27',
#    'Site_Name': '三義',
#    'Site_EName': 'Sanyi',
#    'Area': '竹苗空品區',
#    'County': '苗栗縣',
#    'Township': '三義鄉',
#    'Site_Address': '苗栗縣三義鄉西湖村上湖61-1號',
#    'Longitude': '120.758833',
#    'Latitude': '24.382942',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '32',
#    'Site_Name': '西屯',
#    'Site_EName': 'Xitun',
#    'Area': '中部空品區',
#    'County': '臺中市',
#    'Township': '西屯區',
#    'Site_Address': '臺中市西屯區安和路1號',
#    'Longitude': '120.616917',
#    'Latitude': '24.162197',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '36',
#    'Site_Name': '南投',
#    'Site_EName': 'Nantou',
#    'Area': '中部空品區',
#    'County': '南投縣',
#    'Township': '南投市',
#    'Site_Address': '南投市南陽路269號',
#    'Longitude': '120.685306',
#    'Latitude': '23.913',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '38',
#    'Site_Name': '崙背',
#    'Site_EName': 'Lunbei',
#    'Area': '雲嘉南空品區',
#    'County': '雲林縣',
#    'Township': '崙背鄉',
#    'Site_Address': '雲林縣崙背鄉南陽村大成路91號',
#    'Longitude': '120.348742',
#    'Latitude': '23.757547',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '78',
#    'Site_Name': '馬公',
#    'Site_EName': 'Magong',
#    'Area': '其他',
#    'County': '澎湖縣',
#    'Township': '馬公市',
#    'Site_Address': '澎湖縣馬公市中正路115號',
#    'Longitude': '119.566158',
#    'Latitude': '23.569031',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '43',
#    'Site_Name': '新營',
#    'Site_EName': 'Xinying',
#    'Area': '雲嘉南空品區',
#    'County': '臺南市',
#    'Township': '新營區',
#    'Site_Address': '臺南市新營區中正路4號',
#    'Longitude': '120.31725',
#    'Latitude': '23.305633',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '48',
#    'Site_Name': '橋頭',
#    'Site_EName': 'Qiaotou',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '橋頭區',
#    'Site_Address': '高雄市橋頭區隆豐北路1號',
#    'Longitude': '120.305689',
#    'Latitude': '22.757506',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '50',
#    'Site_Name': '鳳山',
#    'Site_EName': 'Fengshan',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '鳳山區',
#    'Site_Address': '高雄市鳳山區曹公路6號',
#    'Longitude': '120.358083',
#    'Latitude': '22.627392',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211231',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '48',
#    'Site_Name': '橋頭',
#    'Site_EName': 'Qiaotou',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '橋頭區',
#    'Site_Address': '高雄市橋頭區隆豐北路1號',
#    'Longitude': '120.305689',
#    'Latitude': '22.757506',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211230',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '38',
#    'Site_Name': '崙背',
#    'Site_EName': 'Lunbei',
#    'Area': '雲嘉南空品區',
#    'County': '雲林縣',
#    'Township': '崙背鄉',
#    'Site_Address': '雲林縣崙背鄉南陽村大成路91號',
#    'Longitude': '120.348742',
#    'Latitude': '23.757547',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211230',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '36',
#    'Site_Name': '南投',
#    'Site_EName': 'Nantou',
#    'Area': '中部空品區',
#    'County': '南投縣',
#    'Township': '南投市',
#    'Site_Address': '南投市南陽路269號',
#    'Longitude': '120.685306',
#    'Latitude': '23.913',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211230',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '32',
#    'Site_Name': '西屯',
#    'Site_EName': 'Xitun',
#    'Area': '中部空品區',
#    'County': '臺中市',
#    'Township': '西屯區',
#    'Site_Address': '臺中市西屯區安和路1號',
#    'Longitude': '120.616917',
#    'Latitude': '24.162197',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211230',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '27',
#    'Site_Name': '三義',
#    'Site_EName': 'Sanyi',
#    'Area': '竹苗空品區',
#    'County': '苗栗縣',
#    'Township': '三義鄉',
#    'Site_Address': '苗栗縣三義鄉西湖村上湖61-1號',
#    'Longitude': '120.758833',
#    'Latitude': '24.382942',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211230',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '19',
#    'Site_Name': '觀音',
#    'Site_EName': 'Guanyin',
#    'Area': '北部空品區',
#    'County': '桃園市',
#    'Township': '觀音區',
#    'Site_Address': '桃園市觀音區文化路2號',
#    'Longitude': '121.082761',
#    'Latitude': '25.035503',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211230',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '6',
#    'Site_Name': '板橋',
#    'Site_EName': 'Banqiao',
#    'Area': '北部空品區',
#    'County': '新北市',
#    'Township': '板橋區',
#    'Site_Address': '新北市板橋區文化路一段25號',
#    'Longitude': '121.458667',
#    'Latitude': '25.012972',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211230',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '3',
#    'Site_Name': '萬里',
#    'Site_EName': 'Wanli',
#    'Area': '北部空品區',
#    'County': '新北市',
#    'Township': '萬里區',
#    'Site_Address': '新北市萬里區瑪鋉路221號',
#    'Longitude': '121.689881',
#    'Latitude': '25.179667',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211230',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '78',
#    'Site_Name': '馬公',
#    'Site_EName': 'Magong',
#    'Area': '其他',
#    'County': '澎湖縣',
#    'Township': '馬公市',
#    'Site_Address': '澎湖縣馬公市中正路115號',
#    'Longitude': '119.566158',
#    'Latitude': '23.569031',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211230',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '77',
#    'Site_Name': '金門',
#    'Site_EName': 'Kinmen',
#    'Area': '其他',
#    'County': '金門縣',
#    'Township': '金城鎮',
#    'Site_Address': '金門縣金城鎮民權路32號',
#    'Longitude': '118.312256',
#    'Latitude': '24.432133',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211230',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '75',
#    'Site_Name': '馬祖',
#    'Site_EName': 'Matsu',
#    'Area': '其他',
#    'County': '連江縣',
#    'Township': '南竿鄉',
#    'Site_Address': '連江縣南竿鄉介壽村13號',
#    'Longitude': '119.949875',
#    'Latitude': '26.160469',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211230',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '66',
#    'Site_Name': '冬山',
#    'Site_EName': 'Dongshan',
#    'Area': '宜蘭空品區',
#    'County': '宜蘭縣',
#    'Township': '冬山鄉',
#    'Site_Address': '宜蘭縣冬山鄉南興村照安路26號',
#    'Longitude': '121.792928',
#    'Latitude': '24.632203',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211230',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '64',
#    'Site_Name': '陽明',
#    'Site_EName': 'Yangming',
#    'Area': '北部空品區',
#    'County': '臺北市',
#    'Township': '北投區',
#    'Site_Address': '臺北市北投區竹子湖路111號',
#    'Longitude': '121.529583',
#    'Latitude': '25.182722',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211230',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '63',
#    'Site_Name': '花蓮',
#    'Site_EName': 'Hualien',
#    'Area': '花東空品區',
#    'County': '花蓮縣',
#    'Township': '花蓮市',
#    'Site_Address': '花蓮市中正路210號',
#    'Longitude': '121.599769',
#    'Latitude': '23.971306',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211230',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '1',
#    'Item_Unit': 'mm'},
#   {'SiteId': '62',
#    'Site_Name': '臺東',
#    'Site_EName': 'Taitung',
#    'Area': '花東空品區',
#    'County': '臺東縣',
#    'Township': '台東市',
#    'Site_Address': '臺東市中山路276號',
#    'Longitude': '121.15045',
#    'Latitude': '22.755358',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211230',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '61',
#    'Site_Name': '恆春',
#    'Site_EName': 'Hengchun',
#    'Area': '高屏空品區',
#    'County': '屏東縣',
#    'Township': '恆春鎮',
#    'Site_Address': '屏東縣恆春鎮公園路44號',
#    'Longitude': '120.788928',
#    'Latitude': '21.958069',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211230',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '58',
#    'Site_Name': '小港',
#    'Site_EName': 'Xiaogang',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '小港區',
#    'Site_Address': '高雄市小港區平和南路185號',
#    'Longitude': '120.337736',
#    'Latitude': '22.565833',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211230',
# ...
#    'Township': '馬公市',
#    'Site_Address': '澎湖縣馬公市中正路115號',
#    'Longitude': '119.566158',
#    'Latitude': '23.569031',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '77',
#    'Site_Name': '金門',
#    'Site_EName': 'Kinmen',
#    'Area': '其他',
#    'County': '金門縣',
#    'Township': '金城鎮',
#    'Site_Address': '金門縣金城鎮民權路32號',
#    'Longitude': '118.312256',
#    'Latitude': '24.432133',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '75',
#    'Site_Name': '馬祖',
#    'Site_EName': 'Matsu',
#    'Area': '其他',
#    'County': '連江縣',
#    'Township': '南竿鄉',
#    'Site_Address': '連江縣南竿鄉介壽村13號',
#    'Longitude': '119.949875',
#    'Latitude': '26.160469',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '66',
#    'Site_Name': '冬山',
#    'Site_EName': 'Dongshan',
#    'Area': '宜蘭空品區',
#    'County': '宜蘭縣',
#    'Township': '冬山鄉',
#    'Site_Address': '宜蘭縣冬山鄉南興村照安路26號',
#    'Longitude': '121.792928',
#    'Latitude': '24.632203',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '8.5',
#    'Item_Unit': 'mm'},
#   {'SiteId': '64',
#    'Site_Name': '陽明',
#    'Site_EName': 'Yangming',
#    'Area': '北部空品區',
#    'County': '臺北市',
#    'Township': '北投區',
#    'Site_Address': '臺北市北投區竹子湖路111號',
#    'Longitude': '121.529583',
#    'Latitude': '25.182722',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '64',
#    'Item_Unit': 'mm'},
#   {'SiteId': '63',
#    'Site_Name': '花蓮',
#    'Site_EName': 'Hualien',
#    'Area': '花東空品區',
#    'County': '花蓮縣',
#    'Township': '花蓮市',
#    'Site_Address': '花蓮市中正路210號',
#    'Longitude': '121.599769',
#    'Latitude': '23.971306',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0.5',
#    'Item_Unit': 'mm'},
#   {'SiteId': '62',
#    'Site_Name': '臺東',
#    'Site_EName': 'Taitung',
#    'Area': '花東空品區',
#    'County': '臺東縣',
#    'Township': '台東市',
#    'Site_Address': '臺東市中山路276號',
#    'Longitude': '121.15045',
#    'Latitude': '22.755358',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '61',
#    'Site_Name': '恆春',
#    'Site_EName': 'Hengchun',
#    'Area': '高屏空品區',
#    'County': '屏東縣',
#    'Township': '恆春鎮',
#    'Site_Address': '屏東縣恆春鎮公園路44號',
#    'Longitude': '120.788928',
#    'Latitude': '21.958069',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '1.5',
#    'Item_Unit': 'mm'},
#   {'SiteId': '58',
#    'Site_Name': '小港',
#    'Site_EName': 'Xiaogang',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '小港區',
#    'Site_Address': '高雄市小港區平和南路185號',
#    'Longitude': '120.337736',
#    'Latitude': '22.565833',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '50',
#    'Site_Name': '鳳山',
#    'Site_EName': 'Fengshan',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '鳳山區',
#    'Site_Address': '高雄市鳳山區曹公路6號',
#    'Longitude': '120.358083',
#    'Latitude': '22.627392',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '48',
#    'Site_Name': '橋頭',
#    'Site_EName': 'Qiaotou',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '橋頭區',
#    'Site_Address': '高雄市橋頭區隆豐北路1號',
#    'Longitude': '120.305689',
#    'Latitude': '22.757506',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '43',
#    'Site_Name': '新營',
#    'Site_EName': 'Xinying',
#    'Area': '雲嘉南空品區',
#    'County': '臺南市',
#    'Township': '新營區',
#    'Site_Address': '臺南市新營區中正路4號',
#    'Longitude': '120.31725',
#    'Latitude': '23.305633',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '38',
#    'Site_Name': '崙背',
#    'Site_EName': 'Lunbei',
#    'Area': '雲嘉南空品區',
#    'County': '雲林縣',
#    'Township': '崙背鄉',
#    'Site_Address': '雲林縣崙背鄉南陽村大成路91號',
#    'Longitude': '120.348742',
#    'Latitude': '23.757547',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '36',
#    'Site_Name': '南投',
#    'Site_EName': 'Nantou',
#    'Area': '中部空品區',
#    'County': '南投縣',
#    'Township': '南投市',
#    'Site_Address': '南投市南陽路269號',
#    'Longitude': '120.685306',
#    'Latitude': '23.913',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '32',
#    'Site_Name': '西屯',
#    'Site_EName': 'Xitun',
#    'Area': '中部空品區',
#    'County': '臺中市',
#    'Township': '西屯區',
#    'Site_Address': '臺中市西屯區安和路1號',
#    'Longitude': '120.616917',
#    'Latitude': '24.162197',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '27',
#    'Site_Name': '三義',
#    'Site_EName': 'Sanyi',
#    'Area': '竹苗空品區',
#    'County': '苗栗縣',
#    'Township': '三義鄉',
#    'Site_Address': '苗栗縣三義鄉西湖村上湖61-1號',
#    'Longitude': '120.758833',
#    'Latitude': '24.382942',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '19',
#    'Site_Name': '觀音',
#    'Site_EName': 'Guanyin',
#    'Area': '北部空品區',
#    'County': '桃園市',
#    'Township': '觀音區',
#    'Site_Address': '桃園市觀音區文化路2號',
#    'Longitude': '121.082761',
#    'Latitude': '25.035503',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '18.5',
#    'Item_Unit': 'mm'},
#   {'SiteId': '6',
#    'Site_Name': '板橋',
#    'Site_EName': 'Banqiao',
#    'Area': '北部空品區',
#    'County': '新北市',
#    'Township': '板橋區',
#    'Site_Address': '新北市板橋區文化路一段25號',
#    'Longitude': '121.458667',
#    'Latitude': '25.012972',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '13.5',
#    'Item_Unit': 'mm'},
#   {'SiteId': '3',
#    'Site_Name': '萬里',
#    'Site_EName': 'Wanli',
#    'Area': '北部空品區',
#    'County': '新北市',
#    'Township': '萬里區',
#    'Site_Address': '新北市萬里區瑪鋉路221號',
#    'Longitude': '121.689881',
#    'Latitude': '25.179667',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211206',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '35.5',
#    'Item_Unit': 'mm'},
#   {'SiteId': '78',
#    'Site_Name': '馬公',
#    'Site_EName': 'Magong',
#    'Area': '其他',
#    'County': '澎湖縣',
#    'Township': '馬公市',
#    'Site_Address': '澎湖縣馬公市中正路115號',
#    'Longitude': '119.566158',
#    'Latitude': '23.569031',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '77',
#    'Site_Name': '金門',
#    'Site_EName': 'Kinmen',
#    'Area': '其他',
#    'County': '金門縣',
#    'Township': '金城鎮',
#    'Site_Address': '金門縣金城鎮民權路32號',
#    'Longitude': '118.312256',
#    'Latitude': '24.432133',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '75',
#    'Site_Name': '馬祖',
#    'Site_EName': 'Matsu',
#    'Area': '其他',
#    'County': '連江縣',
#    'Township': '南竿鄉',
#    'Site_Address': '連江縣南竿鄉介壽村13號',
#    'Longitude': '119.949875',
#    'Latitude': '26.160469',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '66',
#    'Site_Name': '冬山',
#    'Site_EName': 'Dongshan',
#    'Area': '宜蘭空品區',
#    'County': '宜蘭縣',
#    'Township': '冬山鄉',
#    'Site_Address': '宜蘭縣冬山鄉南興村照安路26號',
#    'Longitude': '121.792928',
#    'Latitude': '24.632203',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '64',
#    'Site_Name': '陽明',
#    'Site_EName': 'Yangming',
#    'Area': '北部空品區',
#    'County': '臺北市',
#    'Township': '北投區',
#    'Site_Address': '臺北市北投區竹子湖路111號',
#    'Longitude': '121.529583',
#    'Latitude': '25.182722',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '27.5',
#    'Item_Unit': 'mm'},
#   {'SiteId': '63',
#    'Site_Name': '花蓮',
#    'Site_EName': 'Hualien',
#    'Area': '花東空品區',
#    'County': '花蓮縣',
#    'Township': '花蓮市',
#    'Site_Address': '花蓮市中正路210號',
#    'Longitude': '121.599769',
#    'Latitude': '23.971306',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '18.5',
#    'Item_Unit': 'mm'},
#   {'SiteId': '62',
#    'Site_Name': '臺東',
#    'Site_EName': 'Taitung',
#    'Area': '花東空品區',
#    'County': '臺東縣',
#    'Township': '台東市',
#    'Site_Address': '臺東市中山路276號',
#    'Longitude': '121.15045',
#    'Latitude': '22.755358',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '2',
#    'Item_Unit': 'mm'},
#   {'SiteId': '3',
#    'Site_Name': '萬里',
#    'Site_EName': 'Wanli',
#    'Area': '北部空品區',
#    'County': '新北市',
#    'Township': '萬里區',
#    'Site_Address': '新北市萬里區瑪鋉路221號',
#    'Longitude': '121.689881',
#    'Latitude': '25.179667',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '35',
#    'Item_Unit': 'mm'},
#   {'SiteId': '6',
#    'Site_Name': '板橋',
#    'Site_EName': 'Banqiao',
#    'Area': '北部空品區',
#    'County': '新北市',
#    'Township': '板橋區',
#    'Site_Address': '新北市板橋區文化路一段25號',
#    'Longitude': '121.458667',
#    'Latitude': '25.012972',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '1',
#    'Item_Unit': 'mm'},
#   {'SiteId': '19',
#    'Site_Name': '觀音',
#    'Site_EName': 'Guanyin',
#    'Area': '北部空品區',
#    'County': '桃園市',
#    'Township': '觀音區',
#    'Site_Address': '桃園市觀音區文化路2號',
#    'Longitude': '121.082761',
#    'Latitude': '25.035503',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '2',
#    'Item_Unit': 'mm'},
#   {'SiteId': '27',
#    'Site_Name': '三義',
#    'Site_EName': 'Sanyi',
#    'Area': '竹苗空品區',
#    'County': '苗栗縣',
#    'Township': '三義鄉',
#    'Site_Address': '苗栗縣三義鄉西湖村上湖61-1號',
#    'Longitude': '120.758833',
#    'Latitude': '24.382942',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '32',
#    'Site_Name': '西屯',
#    'Site_EName': 'Xitun',
#    'Area': '中部空品區',
#    'County': '臺中市',
#    'Township': '西屯區',
#    'Site_Address': '臺中市西屯區安和路1號',
#    'Longitude': '120.616917',
#    'Latitude': '24.162197',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '36',
#    'Site_Name': '南投',
#    'Site_EName': 'Nantou',
#    'Area': '中部空品區',
#    'County': '南投縣',
#    'Township': '南投市',
#    'Site_Address': '南投市南陽路269號',
#    'Longitude': '120.685306',
#    'Latitude': '23.913',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '38',
#    'Site_Name': '崙背',
#    'Site_EName': 'Lunbei',
#    'Area': '雲嘉南空品區',
#    'County': '雲林縣',
#    'Township': '崙背鄉',
#    'Site_Address': '雲林縣崙背鄉南陽村大成路91號',
#    'Longitude': '120.348742',
#    'Latitude': '23.757547',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '43',
#    'Site_Name': '新營',
#    'Site_EName': 'Xinying',
#    'Area': '雲嘉南空品區',
#    'County': '臺南市',
#    'Township': '新營區',
#    'Site_Address': '臺南市新營區中正路4號',
#    'Longitude': '120.31725',
#    'Latitude': '23.305633',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '48',
#    'Site_Name': '橋頭',
#    'Site_EName': 'Qiaotou',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '橋頭區',
#    'Site_Address': '高雄市橋頭區隆豐北路1號',
#    'Longitude': '120.305689',
#    'Latitude': '22.757506',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '50',
#    'Site_Name': '鳳山',
#    'Site_EName': 'Fengshan',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '鳳山區',
#    'Site_Address': '高雄市鳳山區曹公路6號',
#    'Longitude': '120.358083',
#    'Latitude': '22.627392',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '58',
#    'Site_Name': '小港',
#    'Site_EName': 'Xiaogang',
#    'Area': '高屏空品區',
#    'County': '高雄市',
#    'Township': '小港區',
#    'Site_Address': '高雄市小港區平和南路185號',
#    'Longitude': '120.337736',
#    'Latitude': '22.565833',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'},
#   {'SiteId': '61',
#    'Site_Name': '恆春',
#    'Site_EName': 'Hengchun',
#    'Area': '高屏空品區',
#    'County': '屏東縣',
#    'Township': '恆春鎮',
#    'Site_Address': '屏東縣恆春鎮公園路44號',
#    'Longitude': '120.788928',
#    'Latitude': '21.958069',
#    'Agency_Name': '行政院環境保護署',
#    'Monitor_Month': '202112',
#    'Monitor_Date': '20211205',
#    'Item_Name': '雨量累計',
#    'Item_EName': 'RAIN_SUM',
#    'Result_Value': '0',
#    'Item_Unit': 'mm'}],
#  'limit': 1000,
#  'offset': 0,
#  '_links': {'start': '/api/v1/acidr_p_01?format=json&api_key=84a024b0-1d85-460c-b330-d96b9ea12cb9&limit=1000',
#   'next': '/api/v1/acidr_p_01?format=json&api_key=84a024b0-1d85-460c-b330-d96b9ea12cb9&limit=1000&offset=1000'},
#  'distribution': [{'qcLevel': '/result/records'}],
#  'total': 589}
