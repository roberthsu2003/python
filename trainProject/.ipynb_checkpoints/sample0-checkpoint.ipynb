# %%
a = 5
b = 19
a+b
# Out:
# 24

# %%
#int,float,str,bool

a = 10
print(type(a))
a = 10.0
print(type(a))
a = ("10.0")
print(type(a))
a = True
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
