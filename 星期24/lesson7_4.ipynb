# %%
#comprehension -> 快速建立list,dictionary,set,generator

number_list = []
number_list.append(1)
number_list.append(2)
number_list.append(3)
number_list.append(4)
number_list.append(5)
number_list
# Out:
# [1, 2, 3, 4, 5]

# %%
number_list = []
for i in range(1,6):
    number_list.append(i)
number_list
# Out:
# [1, 2, 3, 4, 5]

# %%
#list comprehension[for in]
number_list = [i for i in range(1,6)]
number_list
# Out:
# [1, 2, 3, 4, 5]

# %%
#list comprehension[for in if]
number_list = [i for i in range(1,6) if i % 2 == 1]
number_list
# Out:
# [1, 3, 5]

# %%
#dictionary comprehension{for in}
word = 'letters'
letter_counts = {letter:word.count(letter) for letter in word}
letter_counts
# Out:
# {'l': 1, 'e': 2, 't': 2, 'r': 1, 's': 1}

# %%
#50個學生,每個學生5個分數
import random
students = [[random.randint(60,100) for _ in range(5)] for _ in range(50)]
students
# Out:
# [[62, 71, 89, 85, 65],
#  [88, 65, 82, 94, 82],
#  [90, 62, 69, 87, 74],
#  [92, 66, 90, 94, 65],
#  [85, 64, 73, 66, 98],
#  [69, 75, 64, 98, 79],
#  [63, 99, 60, 85, 72],
#  [80, 73, 93, 73, 71],
#  [72, 88, 63, 71, 69],
#  [89, 67, 97, 65, 91],
#  [96, 94, 66, 78, 98],
#  [87, 81, 74, 75, 82],
#  [82, 82, 79, 66, 70],
#  [64, 77, 100, 87, 65],
#  [90, 73, 96, 96, 94],
#  [94, 72, 99, 65, 87],
#  [79, 88, 72, 66, 77],
#  [74, 90, 69, 71, 99],
#  [68, 65, 62, 89, 95],
#  [100, 60, 92, 79, 95],
#  [94, 82, 65, 67, 67],
#  [93, 68, 61, 81, 82],
#  [68, 78, 68, 87, 86],
#  [67, 73, 76, 80, 63],
#  [87, 68, 63, 100, 96],
#  [75, 94, 63, 72, 88],
#  [80, 90, 60, 85, 71],
#  [95, 86, 100, 68, 99],
#  [78, 89, 80, 77, 62],
#  [100, 77, 75, 86, 63],
#  [100, 86, 96, 67, 84],
#  [83, 100, 61, 79, 80],
#  [71, 74, 64, 69, 63],
#  [62, 80, 74, 91, 72],
#  [72, 74, 93, 95, 81],
#  [74, 97, 88, 76, 81],
#  [77, 78, 79, 82, 81],
#  [96, 92, 60, 99, 79],
#  [90, 97, 74, 91, 86],
#  [92, 91, 89, 61, 96],
#  [93, 62, 69, 67, 90],
#  [76, 69, 75, 78, 97],
#  [91, 77, 67, 77, 96],
#  [89, 75, 65, 99, 73],
#  [96, 95, 93, 86, 94],
#  [94, 94, 87, 70, 72],
#  [78, 65, 89, 64, 65],
#  [60, 82, 93, 83, 92],
#  [83, 66, 74, 78, 79],
#  [90, 68, 83, 90, 83]]

# %%
#50個學生,每個學生5個分數
subjects = ["國文","英文","數學","地理","社會"]
students = [{sub:random.randint(60,100) for sub in subjects} for _ in range(50)]
students
# Out:
# [{'國文': 90, '英文': 97, '數學': 63, '地理': 92, '社會': 76},
#  {'國文': 90, '英文': 81, '數學': 88, '地理': 80, '社會': 66},
#  {'國文': 100, '英文': 79, '數學': 85, '地理': 92, '社會': 82},
#  {'國文': 66, '英文': 86, '數學': 76, '地理': 60, '社會': 77},
#  {'國文': 88, '英文': 85, '數學': 87, '地理': 87, '社會': 80},
#  {'國文': 98, '英文': 71, '數學': 87, '地理': 98, '社會': 95},
#  {'國文': 95, '英文': 100, '數學': 96, '地理': 67, '社會': 64},
#  {'國文': 93, '英文': 89, '數學': 76, '地理': 68, '社會': 93},
#  {'國文': 90, '英文': 82, '數學': 99, '地理': 76, '社會': 76},
#  {'國文': 77, '英文': 60, '數學': 84, '地理': 83, '社會': 87},
#  {'國文': 84, '英文': 82, '數學': 65, '地理': 90, '社會': 78},
#  {'國文': 62, '英文': 70, '數學': 70, '地理': 62, '社會': 70},
#  {'國文': 70, '英文': 61, '數學': 72, '地理': 94, '社會': 98},
#  {'國文': 86, '英文': 98, '數學': 64, '地理': 62, '社會': 85},
#  {'國文': 87, '英文': 91, '數學': 75, '地理': 97, '社會': 100},
#  {'國文': 95, '英文': 79, '數學': 62, '地理': 100, '社會': 89},
#  {'國文': 78, '英文': 99, '數學': 91, '地理': 80, '社會': 96},
#  {'國文': 72, '英文': 74, '數學': 75, '地理': 73, '社會': 86},
#  {'國文': 99, '英文': 64, '數學': 94, '地理': 63, '社會': 80},
#  {'國文': 100, '英文': 68, '數學': 65, '地理': 75, '社會': 98},
#  {'國文': 67, '英文': 64, '數學': 72, '地理': 64, '社會': 66},
#  {'國文': 90, '英文': 60, '數學': 96, '地理': 62, '社會': 65},
#  {'國文': 65, '英文': 100, '數學': 100, '地理': 87, '社會': 99},
#  {'國文': 67, '英文': 62, '數學': 69, '地理': 64, '社會': 72},
#  {'國文': 69, '英文': 83, '數學': 74, '地理': 71, '社會': 96},
#  {'國文': 70, '英文': 94, '數學': 81, '地理': 69, '社會': 88},
#  {'國文': 96, '英文': 71, '數學': 60, '地理': 80, '社會': 75},
#  {'國文': 67, '英文': 74, '數學': 93, '地理': 97, '社會': 87},
#  {'國文': 88, '英文': 70, '數學': 72, '地理': 64, '社會': 74},
#  {'國文': 89, '英文': 91, '數學': 64, '地理': 61, '社會': 61},
#  {'國文': 71, '英文': 89, '數學': 61, '地理': 92, '社會': 69},
#  {'國文': 79, '英文': 87, '數學': 64, '地理': 61, '社會': 80},
#  {'國文': 61, '英文': 73, '數學': 76, '地理': 85, '社會': 90},
#  {'國文': 88, '英文': 76, '數學': 99, '地理': 71, '社會': 80},
#  {'國文': 99, '英文': 68, '數學': 96, '地理': 80, '社會': 84},
#  {'國文': 61, '英文': 74, '數學': 71, '地理': 74, '社會': 94},
#  {'國文': 70, '英文': 91, '數學': 95, '地理': 75, '社會': 99},
#  {'國文': 93, '英文': 76, '數學': 90, '地理': 82, '社會': 98},
#  {'國文': 88, '英文': 66, '數學': 76, '地理': 100, '社會': 89},
#  {'國文': 72, '英文': 78, '數學': 95, '地理': 69, '社會': 71},
#  {'國文': 71, '英文': 63, '數學': 95, '地理': 94, '社會': 62},
#  {'國文': 87, '英文': 91, '數學': 72, '地理': 86, '社會': 98},
#  {'國文': 84, '英文': 99, '數學': 99, '地理': 65, '社會': 85},
#  {'國文': 74, '英文': 100, '數學': 75, '地理': 77, '社會': 72},
#  {'國文': 72, '英文': 60, '數學': 65, '地理': 87, '社會': 70},
#  {'國文': 89, '英文': 95, '數學': 94, '地理': 64, '社會': 83},
#  {'國文': 63, '英文': 62, '數學': 66, '地理': 91, '社會': 68},
#  {'國文': 60, '英文': 69, '數學': 91, '地理': 81, '社會': 69},
#  {'國文': 94, '英文': 60, '數學': 93, '地理': 67, '社會': 91},
#  {'國文': 100, '英文': 83, '數學': 86, '地理': 91, '社會': 62}]
