# %%
import requests
res = requests.request('GET','https://udn.com/news/story/7251/6163955?from=udn_ch2_menu_v2_main_cate')
print(res.__class__)
# Out:
# <class 'requests.models.Response'>

# %%
res.encoding
# Out:
# 'UTF-8'

# %%
res.text
# Out:
# '<!--getArticle 0.0011 --><!--hottest_news long cache--><!--reporter name long cache--><!--extend_news long cache--><!--related_news long cache--><!--content 0.0654 --><!--ad_1 0.0300 --><!--ad 0.0717 --><!--view_type 0.0000 --><!--meta 0.0026 --><!--family_bar 0.0005 --><!--family_bar sub  --><!--breaking_news 0.0011 --><!--top 0.0031 --><!--bottom 0.0022 --><!--nav 0.0000 --><!--code 0.1527 --><!DOCTYPE html>\n<html lang="zh-TW">\n<head>\n<!--\n  <meta charset="UTF-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0">\n  <meta http-equiv="X-UA-Compatible" content="ie=edge">\n  <meta name="description" content="網頁敘述">\n  <meta name="theme-color" content="#f46c00" />\n-->\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n<meta http-equiv="content-language" content="zh-Hant-TW">\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n<!-
# ...

# %%
res.url
# Out:
# 'https://udn.com/news/story/7251/6163955?from=udn_ch2_menu_v2_main_cate'
