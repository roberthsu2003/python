# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax_1 = fig.add_subplot(1,1,1)
x = [0, 1, 2]
y = [3, 4, 5]
ax_1.plot(x,y,'bo')
print(type(ax_1))
ax_1.set_title("First Line Plot")
plt.show()
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
fig = plt.figure(num="fig1",figsize=(8,4),dpi=220,facecolor='gray')
ax_1=fig.add_subplot(1,3,1)
ax_2=fig.add_subplot(1,3,2)
ax_3=fig.add_subplot(1,3,3)
plt.show()

# %%
fig1 = plt.figure(num="fig1",figsize=(8,4),dpi=220,facecolor='gray')
fig1_ax = fig1.add_subplot(1,1,1)
x = [0, 1, 2]
y = [3, 4, 1]
fig1_ax.plot(x, y)

fig2 = plt.figure(num="fig2",figsize=(8,4),dpi=220,facecolor='gray')
fig2_ax = fig2.add_subplot(1,1,1)
x = [2, 3, 6]
y = [3, 1, 1]
fig2_ax.plot(x, y)

plt.show()

# %%
student1 = {"chinese":78, "english":80, "math":92, "history":75, "discover":85}
student2 = {"chinese":92, "english":60, "math":85, "history":62, "discover":73}

subject = list(student1.keys())
student1_num = list(student1.values())
student2_num = list(student2.values())
print(subject)
print(student1_num)
print(student2_num)
# Out:
# ['chinese', 'english', 'math', 'history', 'discover']
# [78, 80, 92, 75, 85]
# [92, 60, 85, 62, 73]

# %%
import matplotlib.pyplot as plt
fig = plt.figure(num="fig1",figsize=(8,4),dpi=220,facecolor='lightgray')
ax = fig.add_subplot(1,1,1)
ax.plot(subject,student1_num,subject,student2_num)
plt.show()
