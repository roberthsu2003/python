# %%
import pandas as pd
ser = pd.Series([4, 7, -5, 3],index=["d", 'b', 'a', "c"])
print(type(ser))
print(ser.dtype)
print(ser.count())
# Out:
# <class 'pandas.core.series.Series'>
# int64
# 4

# %%
#透過索引取出值,更改值
ser.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
ser['a']
# Out:
# -5

# %%
ser['d'] = 10
ser
# Out:
# d    10
# b     7
# a    -5
# c     3
# dtype: int64

# %%
ser[['d','b','a']]
# Out:
# d    10
# b     7
# a    -5
# dtype: int64
