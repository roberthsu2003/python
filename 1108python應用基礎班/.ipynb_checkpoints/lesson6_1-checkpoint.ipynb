# %%
import numpy as np
student = np.array([76, 92, 74, 95, 81])
student
# Out:
# array([76, 92, 74, 95, 81])

# %%
import pandas as pd
student_series = pd.Series(student,index=['國文','英文','數學','社會','自然'])
student_series
# Out:
# 國文    76
# 英文    92
# 數學    74
# 社會    95
# 自然    81
# dtype: int64

# %%
student_series.values
# Out:
# array([76, 92, 74, 95, 81])

# %%
student_series.index
# Out:
# Index(['國文', '英文', '數學', '社會', '自然'], dtype='object')

# %%
student_dict = {"國文":89, "英文":73, "數學":98, "社會":85, "自然":95}
student_dict
# Out:
# {'國文': 89, '英文': 73, '數學': 98, '社會': 85, '自然': 95}

# %%
student_s= pd.Series(student_dict)
student_s
# Out:
# 國文    89
# 英文    73
# 數學    98
# 社會    85
# 自然    95
# dtype: int64

# %%
total = student_series + student_s
total
# Out:
# 國文    165
# 英文    165
# 數學    172
# 社會    180
# 自然    176
# dtype: int64

# %%
total / 2
# Out:
# 國文    82.5
# 英文    82.5
# 數學    86.0
# 社會    90.0
# 自然    88.0
# dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd
sdata = {'Taipei':3500, 'Taoyuan':7100, "Taichung":16000, "Kaohsiung":5000}
obj_s=pd.Series(sdata)
print(obj_s)

fig=plt.figure(figsize=(8,5))
ax1=fig.add_subplot(1,1,1)
ax1.bar(obj_s.index, obj_s.values)
plt.show()
# Out:
# Taipei        3500
# Taoyuan       7100
# Taichung     16000
# Kaohsiung     5000
# dtype: int64

# %%
import numpy as np 
import pandas as pd
scores = np.random.randint(50,101,size=(50,5))
print(scores.ndim)
print(scores.shape)
print(scores.size)
print(scores.dtype)
# Out:
# 2
# (50, 5)
# 250
# int64

# %%
scores_df = pd.DataFrame(data=scores,index=range(1,51),columns=['國文','英文','數學','社會','自然'])
scores_df
# Out:
#      國文   英文   數學   社會  自然
# 1    86   77  100   87  96
# 2    91   80   52   74  64
# 3    55   57   82   57  78
# 4    83   62   95   97  51
# 5    96   62   50   63  63
# 6    89   57   57   79  69
# 7    76   93   81   83  69
# 8    86   86   68  100  61
# 9    53   58  100   59  80
# 10   83   77   65   90  98
# 11   69  100   53   88  65
# 12   82   78   70   60  81
# 13   87   85   97   86  96
# 14   50   53   72   78  94
# 15   54   60   69   91  95
# 16   54   73   69   65  73
# 17   98   81   87   58  87
# 18   68   86   64   50  67
# 19   67   59   75   81  95
# 20   60   63   71   89  95
# 21   93   74   68   57  70
# 22   99   78   85   71  85
# 23   85   75   61   73  83
# 24   91   71   62   74  64
# 25   65   95   68   54  88
# 26   74   86   88   50  64
# 27   58   85   86   90  68
# 28   50   63   73   72  62
# 29   65   61   80   71  61
# 30  100   80  100   94  73
# 31   70   94   52   70  58
# 32   81   58   70   55  73
# 33   78   93   96   98  64
# 34   64   71   62   80  70
# 35   66   89   87   77  53
# 36   96   89   84   96  82
# 37   55   85   73   60  94
# 38   77   77   98   86  93
# 39   83   93   99   56  64
# 40   58   88   91   55  67
# 41   96   87   62   87  91
# 42   94   88   92   58  92
# 43   67   86   78   61  80
# 44   95   66   63   75  70
# 45   63   57   96   56  96
# 46   55   69   91   88  75
# 47   66   82   88   50  64
# 48   77   93   71   68  75
# 49   70   73   80   54  63
# 50   62   94   53   95  66

# %%
sum_values = scores_df.sum(axis=1)
avg_values = scores_df.mean(axis=1)
scores_df['總分'] = sum_values
scores_df['平均'] = avg_values
scores_df
# Out:
#      國文   英文   數學   社會  自然   總分    平均
# 1    86   77  100   87  96  446  89.2
# 2    91   80   52   74  64  361  72.2
# 3    55   57   82   57  78  329  65.8
# 4    83   62   95   97  51  388  77.6
# 5    96   62   50   63  63  334  66.8
# 6    89   57   57   79  69  351  70.2
# 7    76   93   81   83  69  402  80.4
# 8    86   86   68  100  61  401  80.2
# 9    53   58  100   59  80  350  70.0
# 10   83   77   65   90  98  413  82.6
# 11   69  100   53   88  65  375  75.0
# 12   82   78   70   60  81  371  74.2
# 13   87   85   97   86  96  451  90.2
# 14   50   53   72   78  94  347  69.4
# 15   54   60   69   91  95  369  73.8
# 16   54   73   69   65  73  334  66.8
# 17   98   81   87   58  87  411  82.2
# 18   68   86   64   50  67  335  67.0
# 19   67   59   75   81  95  377  75.4
# 20   60   63   71   89  95  378  75.6
# 21   93   74   68   57  70  362  72.4
# 22   99   78   85   71  85  418  83.6
# 23   85   75   61   73  83  377  75.4
# 24   91   71   62   74  64  362  72.4
# 25   65   95   68   54  88  370  74.0
# 26   74   86   88   50  64  362  72.4
# 27   58   85   86   90  68  387  77.4
# 28   50   63   73   72  62  320  64.0
# 29   65   61   80   71  61  338  67.6
# 30  100   80  100   94  73  447  89.4
# 31   70   94   52   70  58  344  68.8
# 32   81   58   70   55  73  337  67.4
# 33   78   93   96   98  64  429  85.8
# 34   64   71   62   80  70  347  69.4
# 35   66   89   87   77  53  372  74.4
# 36   96   89   84   96  82  447  89.4
# 37   55   85   73   60  94  367  73.4
# 38   77   77   98   86  93  431  86.2
# 39   83   93   99   56  64  395  79.0
# 40   58   88   91   55  67  359  71.8
# 41   96   87   62   87  91  423  84.6
# 42   94   88   92   58  92  424  84.8
# 43   67   86   78   61  80  372  74.4
# 44   95   66   63   75  70  369  73.8
# 45   63   57   96   56  96  368  73.6
# 46   55   69   91   88  75  378  75.6
# 47   66   82   88   50  64  350  70.0
# 48   77   93   71   68  75  384  76.8
# 49   70   73   80   54  63  340  68.0
# 50   62   94   53   95  66  370  74.0

# %%
#各鄉鎮市區人口密度.csv的處理

import csv
import pandas as pd
with open('各鄉鎮市區人口密度.csv',mode='r',encoding='utf-8') as file:
    next(file)
    csv_reader = csv.reader(file)
    df = pd.DataFrame(csv_reader,columns=['統計年','區域別','年底人口數','土地面積','人口密度'])
df
# Out:
#      統計年                                                區域別   年底人口數     土地面積  \
# 0    統計年                                                區域別   年底人口數     土地面積
# 1    110                                             新北市板橋區  552713  23.1373
# 2    110                                             新北市三重區  381731   16.317
# 3    110                                             新北市中和區  406140   20.144
# 4    110                                             新北市永和區  214967   5.7138
# ..   ...                                                ...     ...      ...
# 370  110                                               南沙群島       …   0.5045
# 371
# 372                                說明：1.人口密度係指每單位土地面積內之人口數。
# 373       2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)
# 374                ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。
#
#       人口密度
# 0     人口密度
# 1    23888
# 2    23395
# 3    20162
# 4    37622
# ..     ...
# 370      …
# 371
# 372
# 373
# 374
#
# [375 rows x 5 columns]

# %%
df
# Out:
#      統計年                                                區域別   年底人口數     土地面積  \
# 0    統計年                                                區域別   年底人口數     土地面積
# 1    110                                             新北市板橋區  552713  23.1373
# 2    110                                             新北市三重區  381731   16.317
# 3    110                                             新北市中和區  406140   20.144
# 4    110                                             新北市永和區  214967   5.7138
# ..   ...                                                ...     ...      ...
# 370  110                                               南沙群島       …   0.5045
# 371
# 372                                說明：1.人口密度係指每單位土地面積內之人口數。
# 373       2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)
# 374                ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。
#
#       人口密度
# 0     人口密度
# 1    23888
# 2    23395
# 3    20162
# 4    37622
# ..     ...
# 370      …
# 371
# 372
# 373
# 374
#
# [375 rows x 5 columns]

# %%
#取出單欄
df['統計年']
# Out:
# 0      統計年
# 1      110
# 2      110
# 3      110
# 4      110
#       ...
# 370    110
# 371
# 372
# 373
# 374
# Name: 統計年, Length: 375, dtype: object

# %%
#取出單欄
df['年底人口數']
# Out:
# 0       年底人口數
# 1      552713
# 2      381731
# 3      406140
# 4      214967
#         ...
# 370         …
# 371
# 372
# 373
# 374
# Name: 年底人口數, Length: 375, dtype: object

# %%
#取出多欄
df[['統計年','年底人口數']]
# Out:
#      統計年   年底人口數
# 0    統計年   年底人口數
# 1    110  552713
# 2    110  381731
# 3    110  406140
# 4    110  214967
# ..   ...     ...
# 370  110       …
# 371
# 372
# 373
# 374
#
# [375 rows x 2 columns]

# %%
#以index選取列
df.loc[1:100]
# Out:
#      統計年     區域別   年底人口數      土地面積   人口密度
# 1    110  新北市板橋區  552713   23.1373  23888
# 2    110  新北市三重區  381731    16.317  23395
# 3    110  新北市中和區  406140    20.144  20162
# 4    110  新北市永和區  214967    5.7138  37622
# 5    110  新北市新莊區  421381   19.7383  21348
# ..   ...     ...     ...       ...    ...
# 96   110  臺南市學甲區   24981   53.9919    463
# 97   110  臺南市西港區   24495   33.7666    725
# 98   110  臺南市七股區   21757  110.1492    198
# 99   110  臺南市將軍區   18843   41.9796    449
# 100  110  臺南市北門區   10397   44.1003    236
#
# [100 rows x 5 columns]

# %%
#篩選
df['統計年'] == '110'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 370     True
# 371    False
# 372    False
# 373    False
# 374    False
# Name: 統計年, Length: 375, dtype: bool

# %%
#篩選
df[df['統計年'] == '110']
# Out:
#      統計年     區域別   年底人口數     土地面積   人口密度
# 1    110  新北市板橋區  552713  23.1373  23888
# 2    110  新北市三重區  381731   16.317  23395
# 3    110  新北市中和區  406140   20.144  20162
# 4    110  新北市永和區  214967   5.7138  37622
# 5    110  新北市新莊區  421381  19.7383  21348
# ..   ...     ...     ...      ...    ...
# 366  110  連江縣北竿鄉    2998      9.9    303
# 367  110  連江縣莒光鄉    1496      4.7    318
# 368  110  連江縣東引鄉    1494      3.8    393
# 369  110    東沙群島       …     2.38      …
# 370  110    南沙群島       …   0.5045      …
#
# [370 rows x 5 columns]

# %%
新北市 = df[df['區域別'].str.contains('新北市')]

# %%
新北市
# Out:
#     統計年     區域別   年底人口數      土地面積   人口密度
# 1   110  新北市板橋區  552713   23.1373  23888
# 2   110  新北市三重區  381731    16.317  23395
# 3   110  新北市中和區  406140    20.144  20162
# 4   110  新北市永和區  214967    5.7138  37622
# 5   110  新北市新莊區  421381   19.7383  21348
# 6   110  新北市新店區  299696  120.2255   2493
# 7   110  新北市樹林區  181903   33.1288   5491
# 8   110  新北市鶯歌區   88131   21.1248   4172
# 9   110  新北市三峽區  116019  191.4508    606
# 10  110  新北市淡水區  185197   70.6565   2621
# 11  110  新北市汐止區  205990   71.2354   2892
# 12  110  新北市瑞芳區   38449   70.7336    544
# 13  110  新北市土城區  237484   29.5578   8035
# 14  110  新北市蘆洲區  201489    7.4351  27100
# 15  110  新北市五股區   90465   34.8632   2595
# 16  110  新北市泰山區   77451   19.1603   4042
# 17  110  新北市林口區  124628   54.1519   2301
# 18  110  新北市深坑區   23646   20.5787   1149
# 19  110  新北市石碇區    7487  144.3498     52
# 20  110  新北市坪林區    6619   170.835     39
# 21  110  新北市三芝區   22357   65.9909    339
# 22  110  新北市石門區   11193   51.2645    218
# 23  110  新北市八里區   40178   39.4933   1017
# 24  110  新北市平溪區    4333   71.3382     61
# 25  110  新北市雙溪區    8235  146.2484     56
# 26  110  新北市貢寮區   11534   99.9734    115
# 27  110  新北市金山區   20844   49.2132    424
# 28  110  新北市萬里區   21462   63.3766    339
# 29  110  新北市烏來區    6391  321.1306     20
