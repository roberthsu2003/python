# %%
print("這是我python的第一個程式")
# Out:
# 這是我python的第一個程式

# %%
a = 5
a
# Out:
# 5

# %%
b = 10
b
# Out:
# 10

# %%
a + b
# Out:
# 15

# %%
#以下的內容是要 a * b
a * b
# Out:
# 50

# %%
a / b #a除以b
# Out:
# 0.5

# %%
a = 12345
print(a)
b = 56789
b
# Out:
# 12345
# 56789
