# %% [markdown]
# <a href="https://colab.research.google.com/github/roberthsu2003/python/blob/master/%E6%B3%95%E5%8B%99%E9%83%A8/practice2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello! World!")
# Out:
# Hello! World!

# %% [markdown]
# ### 梯形面積計算
#
# 讓使用者輸入梯形的上底、下底與高，並計算其面積

# %%
top = float(input('請輸入梯形的上底：'))
bottom = float(input('請輸入梯形的下底：'))
height = float(input('請輸入梯形的高：'))

area = (top + bottom) * height / 2

# 使用 round() 進行四捨五入至小數點後兩位
#print(f'梯形的面積為：{round(area, 2)}')
print(f'梯形的面積為：{round(area, ndigits=2)}')
# Out:
# 請輸入梯形的上底：31.3
# 請輸入梯形的下底：24.5
# 請輸入梯形的高：19.7
# 梯形的面積為：549.63

# %% [markdown]
# ### 直角三角形角度計算 (使用 math 模組)
#
# 輸入直角三角形的對邊及斜邊長度，計算其夾角角度

# %%
import math

opposite = float(input('請輸入對邊長度：'))
hypotenuse = float(input('請輸入斜邊長度：'))

# 使用 asin(對邊/斜邊) 計算弧度
radians = math.asin(opposite / hypotenuse)

# 將弧度轉換為角度
degrees = math.degrees(radians)

print(f'該夾角角度為：{degrees:.2f} 度')
# Out:
# 請輸入對邊長度：25
# 請輸入斜邊長度：50
# 該夾角角度為：30.00 度
