# %%
import requests
from requests import ConnectionError,HTTPError,Timeout

url = 'https://data.ntpc.gov.tw/api/datasets/71CD1490-A2DF-4198-BEF1-318479775E8A/json?page=0&size=1000'
try:
    response = requests.get(url)
    response.raise_for_status()
except ConnectionError:
    print('找不到伺服器')
except HTTPError:
    print('網頁找不到')
except Timeout:
    print('超過時間沒有回應')
else:
    print('沒有發生錯誤')
# Out:
# 沒有發生錯誤

# %%
import numpy as np
import pandas as pd
records=response.json()
pd.DataFrame(records)
# Out:
#       sno           sna tot sbi sarea            mday        lat         lng  \
# 0    1001          大鵬華城  38  14   新店區  20210919160433   24.99116   121.53398
# 1    1002         汐止火車站  56  48   汐止區  20210919160423  25.068914  121.662748
# 2    1003         汐止區公所  46  12   汐止區  20210919160444  25.064162  121.658301
# 3    1004        國泰綜合醫院  56  21   汐止區  20210919160422   25.07315  121.662555
# 4    1005          裕隆公園  40  22   新店區  20210919160426  24.979649  121.546319
# ..    ...           ...  ..  ..   ...             ...        ...         ...
# 662  1758        中山溫泉公園  50   0   金山區  20210919160419  25.221080  121.641770
# 663  1759  學士學府路口(大苑社區)  40   0   土城區  20210913170158  24.976690  121.445270
# 664  1760         龍米停車場  36   1   八里區  20210919160439  25.156780  121.436040
# 665  1761          雙和醫院  30  14   中和區  20210919160441  24.993670  121.494110
# 666  1763   捷運三重站(1號出口)  40   8   三重區  20210919160427  25.054640  121.483220
#
#                                   ar         sareaen  \
# 0                    新北市新店區中正路700巷3號   Xindian Dist.
# 1                     南昌街/新昌路口(西側廣場)     Xizhi Dist.
# 2    新台五路一段/仁愛路口(新台五路側汐止地政事務所前機車停車場)     Xizhi Dist.
# 3                        建成路78號對面停車場     Xizhi Dist.
# 4                      寶中路/品牌路口(東南側)   Xindian Dist.
# ..                               ...             ...
# 662                       民生路204號(旁)   Jinshan Dist.
# 663                 學士路/學府路(西北側建案基地)   Tucheng Dist.
# 664                     龍米路二段150號(旁)      Bali Dist.
# 665                    中正路281號(公車亭旁)   Zhonghe Dist.
# 666                        捷運路36號(旁)  Sanchong Dist.
#
#                              snaen  \
# 0                 Dapeng Community
# 1            Xizhi Railway Station
# 2               Xizhi Dist. Office
# 3          Cathay General Hospital
# 4                       Yulon Park
# ..                             ...
# 662         Zhongshan Spring Park
# 663  Xueshi & Xuefu Intersection
# 664             Longmi Parking Lot
# 665             Shuang Ho Hospital
# 666  MRT Sanchong Station (Exit.1)
#
#                                                   aren bemp act
# 0    No. 3, Lane 700 Chung Cheng Road, Xindian Dist...   24   1
# 1                            Nanchang St./Xinchang Rd.    6   1
# 2                    Sec. 1, Xintai 5th Rd./Ren’ai Rd.   34   1
# 3                                   No78, Jiancheng Rd   34   1
# 4                                        Baozhong Rd./   18   1
# ..                                                 ...  ...  ..
# 662                              No. 204, Minsheng Rd.    0   0
# 663                      Xueshi & Xuefu Intersection      0   1
# 664                        No. 150, Sec. 2, Longmi Rd.   34   1
# 665                            No. 281, Zhongzheng Rd.   15   1
# 666                          No. 36, Jieyun Rd. (Side)   30   1
#
# [667 rows x 14 columns]
