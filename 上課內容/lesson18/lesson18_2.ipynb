# %%
import numpy as np
import pandas as pd

dataFrame = pd.read_csv('各鄉鎮市區人口密度.csv')
dataFrame.columns = dataFrame.loc[0]
dataFrame.drop(index=0,inplace=True)
dataFrame = dataFrame[:-5]
dataFrame
# Out:
# 0    統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    145
# 368  106  連江縣東引鄉    1352      3.8    250
# 369  106    東沙群島      …      2.38     …
# 370  106    南沙群島      …    0.5045     …
#
# [370 rows x 5 columns]

# %%
def a(x):
    if len(x) > 4:
        return x[:3]
    else:
        return x
    
    
dataFrame['區域別'].map(a)
# Out:
# 1       新北市
# 2       新北市
# 3       新北市
# 4       新北市
# 5       新北市
#        ...
# 366     連江縣
# 367     連江縣
# 368     連江縣
# 369    東沙群島
# 370    南沙群島
# Name: 區域別, Length: 370, dtype: object

# %%
state = dataFrame['區域別'].map(lambda x:x[:3] if len(x) > 4 else x)
dataFrame['縣市'] = state
dataFrame
# Out:
# 0    統計年     區域別   年底人口數     土地面積   人口密度    縣市
# 1    106  新北市板橋區  551480  23.1373  23835   新北市
# 2    106  新北市三重區  387484   16.317  23747   新北市
# 3    106  新北市中和區  413590   20.144  20532   新北市
# 4    106  新北市永和區  222585   5.7138  38956   新北市
# 5    106  新北市新莊區  416524  19.7383  21102   新北市
# ..   ...     ...     ...      ...    ...   ...
# 366  106  連江縣北竿鄉    2360      9.9    238   連江縣
# 367  106  連江縣莒光鄉    1624      4.7    145   連江縣
# 368  106  連江縣東引鄉    1352      3.8    250   連江縣
# 369  106    東沙群島      …      2.38     …   東沙群島
# 370  106    南沙群島      …    0.5045     …   南沙群島
#
# [370 rows x 6 columns]

# %%
areas=dataFrame['區域別'].map(lambda x:x[-3:] if len(x)>4 else x)
dataFrame['區域別'] = areas
dataFrame=dataFrame.reindex(columns=['縣市','年底人口數','土地面積'])

# %%
dataFrame.dtypes
# Out:
# 0
# 縣市       object
# 年底人口數    object
# 土地面積     object
# dtype: object

# %%
#dataFrame['年底人口數'].astype(np.int32)
def toInt(x):
    try:
        return int(x)
    except:
        return 0
dataFrame['年底人口數'] = dataFrame['年底人口數'].map(toInt)
dataFrame['土地面積'] = dataFrame['土地面積'].astype(np.float32)

# %%
dataFrame
# Out:
# 0      縣市   年底人口數       土地面積
# 1     新北市  551480  23.137300
# 2     新北市  387484  16.316999
# 3     新北市  413590  20.143999
# 4     新北市  222585   5.713800
# 5     新北市  416524  19.738300
# ..    ...     ...        ...
# 366   連江縣    2360   9.900000
# 367   連江縣    1624   4.700000
# 368   連江縣    1352   3.800000
# 369  東沙群島       0   2.380000
# 370  南沙群島       0   0.504500
#
# [370 rows x 3 columns]
