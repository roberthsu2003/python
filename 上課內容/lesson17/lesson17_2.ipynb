# %%
import numpy as np
import pandas as pd
result=pd.read_csv('ex6.csv')
result.index.name = "編號"
result
# Out:
#            one       two     three      four key
# 編號
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]

# %%
newResult = result.reset_index().set_index(['key','編號'])
newResult
# Out:
#                one       two     three      four
# key 編號
# L   0     0.467976 -0.038649 -0.295344 -1.824726
# B   1    -0.358893  1.404453  0.704965 -0.200638
# G   2    -0.501840  0.659254 -0.421691 -0.057688
# R   3     0.204886  1.074134  1.388361 -0.982404
# Q   4     0.354628 -0.133116  0.283763 -0.837063
# ...            ...       ...       ...       ...
# L   9995  2.311896 -0.417070 -1.409599 -0.515821
# E   9996 -0.479893 -0.650419  0.745152 -0.646038
# K   9997  0.523331  0.787112  0.486066  1.093156
# G   9998 -0.362559  0.598894 -1.843201  0.887292
# 0   9999 -0.096376 -1.012999 -0.657431 -0.573315
#
# [10000 rows x 4 columns]

# %%
newResult=newResult.sort_index(level='key')
newResult
# Out:
#                one       two     three      four
# key 編號
# 0   101  -0.039105 -0.069510 -1.358052 -0.292859
#     142   0.210544 -0.909438  0.903900  0.471579
#     168   0.947171  0.328539  0.194055 -0.530855
#     197  -0.158497  1.349013 -0.475158 -1.033059
#     429  -0.203604 -0.371016 -0.120285 -1.316813
# ...            ...       ...       ...       ...
# Z   9774 -1.649719 -0.588896 -0.542998 -1.429529
#     9878 -1.023229 -1.664268  1.294334  0.333396
#     9901 -0.759939  0.105655  0.051760  1.124987
#     9942 -0.030498 -0.380566  0.482507  0.004529
#     9972 -1.627051 -0.978151  0.154745 -1.229037
#
# [10000 rows x 4 columns]

# %%
newResult['one']
# Out:
# key  編號
# 0    101    -0.039105
#      142     0.210544
#      168     0.947171
#      197    -0.158497
#      429    -0.203604
#                ...
# Z    9774   -1.649719
#      9878   -1.023229
#      9901   -0.759939
#      9942   -0.030498
#      9972   -1.627051
# Name: one, Length: 10000, dtype: float64

# %%
newResult.loc['0']
# Out:
#            one       two     three      four
# 編號
# 101  -0.039105 -0.069510 -1.358052 -0.292859
# 142   0.210544 -0.909438  0.903900  0.471579
# 168   0.947171  0.328539  0.194055 -0.530855
# 197  -0.158497  1.349013 -0.475158 -1.033059
# 429  -0.203604 -0.371016 -0.120285 -1.316813
# ...        ...       ...       ...       ...
# 9811 -0.197311  1.499384 -0.450783 -0.543044
# 9866 -0.751565  1.868232  0.088694  0.470143
# 9948 -0.891974  0.507888 -0.220683  0.062233
# 9963 -0.830696  2.152076  1.159642  1.237279
# 9999 -0.096376 -1.012999 -0.657431 -0.573315
#
# [151 rows x 4 columns]

# %%
newSerial = newResult['one']
newSerial
# Out:
# key  編號
# 0    101    -0.039105
#      142     0.210544
#      168     0.947171
#      197    -0.158497
#      429    -0.203604
#                ...
# Z    9774   -1.649719
#      9878   -1.023229
#      9901   -0.759939
#      9942   -0.030498
#      9972   -1.627051
# Name: one, Length: 10000, dtype: float64

# %%
newSerial.unstack()
# Out:
# 編號       0         1        2         3         4        5         6     \
# key
# 0         NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 1         NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 2         NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 3         NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 4         NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 5         NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 6         NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 7         NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 8         NaN       NaN      NaN       NaN       NaN      NaN       NaN
# 9         NaN       NaN      NaN       NaN       NaN      NaN       NaN
# A         NaN       NaN      NaN       NaN       NaN      NaN       NaN
# B         NaN -0.358893      NaN       NaN       NaN      NaN       NaN
# ...

# %%
newSerial.groupby(level='key').sum()
# Out:
# key
# 0     1.665408
# 1    11.425734
# 2   -12.027358
# 3    42.100302
# 4     3.369031
# 5   -21.339628
# 6    23.546088
# 7    13.590415
# 8    -0.013861
# 9     9.765136
# A    38.897269
# B    15.440654
# C     7.088463
# D     2.301488
# E     7.847879
# F    26.900181
# G   -17.480410
# H    -7.082552
# I     8.148561
# J    16.241878
# K    51.695215
# L    17.545360
# M     1.186659
# N    14.999531
# O   -10.002795
# P     9.425316
# Q   -13.331859
# R    38.933116
# S    23.171948
# T    48.116511
# U    16.968534
# V    -3.523774
# W    49.312915
# X    27.783672
# Y    16.990201
# Z    -2.153618
# Name: one, dtype: float64

# %%
newSerial.groupby(level='key').describe()
# Out:
#      count      mean       std       min       25%       50%       75%  \
# key
# 0    151.0  0.011029  0.959541 -2.825997 -0.580527  0.005817  0.629865
# 1    146.0  0.078258  0.959080 -2.576925 -0.414999  0.166625  0.676484
# 2    152.0 -0.079127  0.954594 -2.825997 -0.772981 -0.093693  0.527847
# 3    162.0  0.259878  0.995871 -2.825997 -0.356773  0.283128  0.999538
# 4    171.0  0.019702  0.943016 -1.946231 -0.647876 -0.003943  0.692476
# 5    157.0 -0.135921  0.948006 -2.405019 -0.838191 -0.109962  0.554389
# 6    166.0  0.141844  0.960701 -2.825997 -0.521073  0.173946  0.871169
# 7    164.0  0.082868  1.020554 -2.548389 -0.678063  0.086778  0.770236
# 8    162.0 -0.000086  0.902729 -2.576925 -0.665566 -0.020713  0.569025
# 9    150.0  0.065101  0.896976 -2.286471 -0.544930  0.062795  0.610179
# A    320.0  0.121554  0.896847 -2.687335 -0.411176  0.120263  0.746474
# B    302.0  0.051128  0.946063 -2.576925 -0.650798  0.109848  0.759167
# ...
