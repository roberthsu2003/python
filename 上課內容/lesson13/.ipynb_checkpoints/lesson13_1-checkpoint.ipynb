# %%
import pandas as pd
obj = pd.Series([4, 7, -5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
obj2 = pd.Series([4, 7, -5, 3], index=['d', 'b', 'a', 'c'])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2['a']
# Out:
# -5

# %%
obj2.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
obj2.values
# Out:
# array([ 4,  7, -5,  3])

# %%
obj2['a'] = 5
obj2
# Out:
# d    4
# b    7
# a    5
# c    3
# dtype: int64

# %%
obj2[['a', 'b', 'c']]
# Out:
# a    5
# b    7
# c    3
# dtype: int64

# %%
obj3 = pd.Series([80, 90, 75, 65], index=['chinese', 'english', 'math', 'history'])
obj3
# Out:
# chinese    80
# english    90
# math       75
# history    65
# dtype: int64

# %%
obj3['chinese']
# Out:
# 80

# %%
obj3[obj3 >= 80]
# Out:
# chinese    80
# english    90
# dtype: int64

# %%
obj3 * 1.1
# Out:
# chinese    88.0
# english    99.0
# math       82.5
# history    71.5
# dtype: float64

# %%
obj3 * 1.05
# Out:
# chinese    84.00
# english    94.50
# math       78.75
# history    68.25
# dtype: float64

# %%
sdata = {'台北':35000, '桃園':71000, '台中':16000, '高雄':5000}
obj4 = pd.Series(sdata)
obj4
# Out:
# 台北    35000
# 桃園    71000
# 台中    16000
# 高雄     5000
# dtype: int64

# %%
import matplotlib.pyplot as plt

sdata5 = {'Taipei':35000, 'Taoyuan':71000, 'Taichung':16000, 'Kaohsiung':5000}
obj5 = pd.Series(sdata5)
plt.bar(obj5.index,obj5.values)
# Out:
# <BarContainer object of 4 artists>
