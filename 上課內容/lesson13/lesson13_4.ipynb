# %%
import numpy as np

scores_data = np.random.randint(50,101,size=(50,5))
scores_data
# Out:
# array([[ 71,  65,  90,  51,  83],
#        [ 91,  61,  93,  70,  74],
#        [ 57,  66,  80,  56,  96],
#        [ 85,  85,  81,  58, 100],
#        [ 64,  59,  54,  66,  68],
#        [ 68,  59,  62,  72,  69],
#        [ 99,  57,  91,  73,  63],
#        [ 87,  99,  69,  60,  78],
#        [ 71,  71,  80,  54,  51],
#        [ 98,  85,  86,  82,  80],
#        [ 68,  80,  97,  98,  69],
#        [ 96,  67,  90,  76,  71],
#        [ 97,  64,  87,  89,  88],
#        [ 64,  76,  51,  75,  91],
#        [ 89,  92,  54,  96,  87],
#        [ 77,  60,  76,  84,  68],
#        [ 53,  73,  81,  89,  78],
#        [ 91,  57,  89,  81,  70],
#        [100,  89,  76,  50,  84],
#        [ 50,  62,  81,  55,  88],
#        [ 62,  60,  95,  94,  73],
#        [ 54,  51,  54,  84,  62],
#        [ 77,  51,  64,  87,  72],
#        [ 84,  51,  76,  84,  81],
#        [ 68,  78,  71,  84,  98],
#        [ 61,  81,  99,  60,  68],
#        [ 50,  53,  67,  80,  65],
# ...

# %%
import pandas as pd
scores_frame=pd.DataFrame(scores_data,columns=['國文','英文','數學','地理','歷史'],index=range(1,51))
scores_frame.columns.name='科目'
scores_frame.index.name = '學號'
scores_frame
# Out:
# 科目   國文   英文   數學  地理   歷史
# 學號
# 1    71   65   90  51   83
# 2    91   61   93  70   74
# 3    57   66   80  56   96
# 4    85   85   81  58  100
# 5    64   59   54  66   68
# 6    68   59   62  72   69
# 7    99   57   91  73   63
# 8    87   99   69  60   78
# 9    71   71   80  54   51
# 10   98   85   86  82   80
# 11   68   80   97  98   69
# 12   96   67   90  76   71
# 13   97   64   87  89   88
# 14   64   76   51  75   91
# 15   89   92   54  96   87
# 16   77   60   76  84   68
# 17   53   73   81  89   78
# 18   91   57   89  81   70
# 19  100   89   76  50   84
# 20   50   62   81  55   88
# 21   62   60   95  94   73
# 22   54   51   54  84   62
# 23   77   51   64  87   72
# 24   84   51   76  84   81
# 25   68   78   71  84   98
# 26   61   81   99  60   68
# 27   50   53   67  80   65
# 28   75   75   60  92   68
# 29   95   73   73  74   73
# 30   60   97  100  52   81
# 31   94   67   82  68   85
# 32   52   62   56  64   59
# 33   85   72   61  75   53
# ...
