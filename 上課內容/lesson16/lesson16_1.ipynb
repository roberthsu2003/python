# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = {'年廣告費投入':[12.5, 15.3, 23.2, 26.4, 33.5, 34.4, 39.4, 45.2, 55.4, 60.9],
       '月均銷售額':[21.2, 23.9, 32.9, 34.1, 42.5, 43.2, 49.0, 52.8, 59.4, 63.5]}
dataFrame = pd.DataFrame(data,index=[2020,2019,2018,2017,2016,2015,2014,2013,2012,2011])
dataFrame
# Out:
#       年廣告費投入  月均銷售額
# 2020    12.5   21.2
# 2019    15.3   23.9
# 2018    23.2   32.9
# 2017    26.4   34.1
# 2016    33.5   42.5
# 2015    34.4   43.2
# 2014    39.4   49.0
# 2013    45.2   52.8
# 2012    55.4   59.4
# 2011    60.9   63.5

# %%
plt.plot(dataFrame.values)

# %%
dataFrame['年廣告費投入'].corr(dataFrame['月均銷售額'])
# Out:
# 0.9941983762371884

# %%
import pandas_datareader.data as web
web.get_data_yahoo('2330.TW')
# Out:
#              High    Low   Open  Close      Volume   Adj Close
# Date
# 2016-09-13  176.5  173.5  176.5  175.5  36834000.0  150.701401
# 2016-09-14  176.0  173.5  174.0  174.0  52877000.0  149.413391
# 2016-09-19  183.0  178.5  179.5  183.0  57055000.0  157.141647
# 2016-09-20  183.5  181.5  182.0  183.5  23641000.0  157.570984
# 2016-09-21  184.0  180.5  181.0  184.0  25008000.0  158.000336
# ...           ...    ...    ...    ...         ...         ...
# 2021-09-06  638.0  621.0  623.0  631.0  55589014.0  631.000000
# 2021-09-07  634.0  623.0  634.0  623.0  26526056.0  623.000000
# 2021-09-08  627.0  612.0  622.0  619.0  37817737.0  619.000000
# 2021-09-09  620.0  610.0  612.0  619.0  18735512.0  619.000000
# 2021-09-10  623.0  614.0  615.0  622.0  16304725.0  622.000000
#
# [1217 rows x 6 columns]

# %%
all_data = {ticker:web.get_data_yahoo(ticker) for ticker in ['2330.TW','2303.TW','2337.TW','2344.TW']}
detail_data = {ticker:data['Adj Close'] for ticker, data in all_data.items()}
prices = pd.DataFrame(detail_data)
prices
# Out:
#                2330.TW    2303.TW    2337.TW    2344.TW
# Date
# 2016-09-13  150.701401   9.473576   6.562965   8.384083
# 2016-09-14  149.413391   9.350542   6.513246   8.426002
# 2016-09-19  157.141647   9.514586   6.629258   8.467922
# 2016-09-20  157.570984   9.473576   6.662404   8.467922
# 2016-09-21  158.000336   9.678632   6.645831   8.551765
# ...                ...        ...        ...        ...
# 2021-09-06  631.000000  69.900002  39.960014  30.299999
# 2021-09-07  623.000000  68.199997  40.299892  30.150000
# 2021-09-08  619.000000  65.800003  38.900002  28.850000
# 2021-09-09  619.000000  67.500000  38.900002  29.400000
# 2021-09-10  622.000000  68.199997  40.049999  30.100000
#
# [1217 rows x 4 columns]

# %%
prices.rename(columns={'2330.TW':'台積電','2303.TW':'聯電','2337.TW':'旺宏','2344.TW':'華邦電'},inplace=True)

# %%
prices
# Out:
#                    台積電         聯電         旺宏        華邦電
# Date
# 2016-09-13  150.701401   9.473576   6.562965   8.384083
# 2016-09-14  149.413391   9.350542   6.513246   8.426002
# 2016-09-19  157.141647   9.514586   6.629258   8.467922
# 2016-09-20  157.570984   9.473576   6.662404   8.467922
# 2016-09-21  158.000336   9.678632   6.645831   8.551765
# ...                ...        ...        ...        ...
# 2021-09-06  631.000000  69.900002  39.960014  30.299999
# 2021-09-07  623.000000  68.199997  40.299892  30.150000
# 2021-09-08  619.000000  65.800003  38.900002  28.850000
# 2021-09-09  619.000000  67.500000  38.900002  29.400000
# 2021-09-10  622.000000  68.199997  40.049999  30.100000
#
# [1217 rows x 4 columns]

# %%
price2020 = prices.loc['2020-01-01':'2020-12-31']
price2020
# Out:
#                    台積電         聯電         旺宏        華邦電
# Date
# 2020-01-02  326.939240  15.261726  35.552711  19.393524
# 2020-01-03  327.421478  15.031187  35.552711  19.640261
# 2020-01-06  320.188263  14.800647  36.441528  19.196135
# 2020-01-07  317.777222  14.754539  35.178471  18.801355
# 2020-01-08  317.777222  14.524000  36.020512  18.850704
# ...                ...        ...        ...        ...
# 2020-12-25  506.813049  45.277664  39.231705  26.547428
# 2020-12-28  510.780243  47.069397  42.533379  29.182285
# 2020-12-29  510.780243  45.907192  40.639771  28.237713
# 2020-12-30  520.698303  46.778847  41.125309  29.729141
# 2020-12-31  525.657349  45.665066  41.076756  28.883999
#
# [245 rows x 4 columns]

# %%
figure = plt.figure()
plt.plot(price2020.values)
plt.show()
