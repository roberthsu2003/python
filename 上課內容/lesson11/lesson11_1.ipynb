# %%
import matplotlib.pyplot as plt
x = ['chinese', 'english', 'math', 'history', 'discover']
y1 = [1, 2, 5, 6, 7]
y2 = [4, 5, 6, 7, 8]
plt.figure(figsize=(8,5))
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %%
x = ['chinese', 'english', 'math', 'history', 'discover']
y1 = [1, 2, 5, 6, 7]
y2 = [4, 5, 6, 7, 8]
plt.figure(figsize=(8,5))
plt.bar(x,y1,align="edge",width=0.2,color='b')
plt.bar(x,y2,align="edge",width=-0.2,color='g')
plt.show()

# %%
#使用list的做法，建立總分
import random
chinese = [random.randint(60,100) for _ in range(50)]
english = [random.randint(60,100) for _ in range(50)]
print(f'chinese={chinese}')
print(f'english={english}')
# Out:
# chinese=[87, 76, 85, 71, 78, 61, 84, 64, 67, 82, 81, 92, 96, 91, 71, 72, 80, 69, 91, 86, 60, 74, 74, 65, 90, 86, 93, 62, 79, 67, 74, 69, 79, 75, 76, 93, 69, 68, 92, 80, 79, 94, 82, 86, 98, 84, 87, 61, 89, 96]
# english=[67, 62, 67, 91, 74, 80, 91, 62, 90, 74, 69, 67, 87, 66, 84, 100, 92, 82, 82, 79, 65, 74, 79, 66, 97, 88, 66, 85, 95, 99, 69, 66, 92, 77, 97, 78, 89, 73, 96, 64, 96, 94, 100, 95, 83, 100, 92, 98, 79, 78]

# %%
result = [chinese[i]+english[i] for i in range(50)]
print(f'總分={result}')
# Out:
# 總分=[154, 138, 152, 162, 152, 141, 175, 126, 157, 156, 150, 159, 183, 157, 155, 172, 172, 151, 173, 165, 125, 148, 153, 131, 187, 174, 159, 147, 174, 166, 143, 135, 171, 152, 173, 171, 158, 141, 188, 144, 175, 188, 182, 181, 181, 184, 179, 159, 168, 174]
