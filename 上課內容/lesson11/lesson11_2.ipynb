# %%
import numpy as np
import math
import matplotlib.pyplot as plt

t = np.arange(0,2.5,0.1)
y1 = np.sin(t * math.pi)
y2 = np.sin(t * math.pi + math.pi/2)
y3 = np.sin(t * math.pi - math.pi/2)
plt.figure(figsize=(8,5))
plt.plot(t,y1)
plt.plot(t,y2)
plt.plot(t,y3)
plt.show()

# %%
t = np.arange(0, 5, 0.1)
y1 = np.sin(math.pi * t)
y2 = np.sin(math.pi * t + math.pi/2)
plt.figure(figsize=(8,5))
plt.subplot(211)
plt.plot(t,y1, 'b-.')
plt.subplot(212)
plt.plot(t,y2, 'r--')
plt.show()

# %%
plt.figure(figsize=(8,3))
plt.axis([0,5,0,20])
plt.title("My Firest Plot")
plt.xlabel("Counting")
plt.ylabel("Square values")
plt.plot([1,2,3,4],[1, 4, 9, 16], 'ro')

# %%
students=np.random.randint(50,101,size=(2,5))
students
print(students)
students[0]
# Out:
# [[84 89 97 85 80]
#  [92 58 99 71 77]]
# 97

# %%
subs = ['chinese','english','math','graphic', 'history']
plt.figure(figsize=(8,5))
plt.title('students')
plt.xlabel('subject')
plt.ylabel('score')
plt.plot(subs,students[0],'ro-')
plt.plot(subs,students[1],'go-')
plt.show()

# %%
students=np.random.randint(50,101,size=(10,5))

# %%
subs = ['chinese','english','math','graphic', 'history']
plt.figure(figsize=(8,5))
plt.title('students')
plt.xlabel('subject')
plt.ylabel('score')
for i in students:
    plt.plot(subs,i,'o-')
plt.show()
