# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

font = FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8) #forMac
#font = FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8) #forWindow

# %%
xlsx = pd.ExcelFile('總統.xls')
all=pd.read_excel(xlsx,'中　央')
all
# Out:
#    第14任總統、副總統選舉候選人得票數一覽表     Unnamed: 1     Unnamed: 2     Unnamed: 3  \
# 0                   行政區別      各組候選人得票情形            NaN            NaN
# 1                    NaN  (1)\n朱立倫\n王如玄  (2)\n蔡英文\n陳建仁  (3)\n宋楚瑜\n徐欣瑩
# 2                    NaN            NaN            NaN            NaN
# 3                    NaN            NaN            NaN            NaN
# 4                    總　計        3813365        6894744        1576861
# 5                   　臺北市         546491         757383         153804
# 6                   　新北市         709374        1165888         252486
# 7                   　桃園市         369013         547573         156518
# 8                   　臺中市         430005         793281         218810
# 9                   　臺南市         219196         670608         103432
# 10                  　高雄市         391823         955168         159765
# 11                  　新竹縣          94603         114023          59510
# ...

# %%
df=all.iloc[5:,:4]
df.columns = ['縣市','朱立倫','蔡英文','宋楚瑜']
df.name='第14任總統、副總統選舉候選人得票數一覽表'
df
# Out:
#       縣市     朱立倫      蔡英文     宋楚瑜
# 5   　臺北市  546491   757383  153804
# 6   　新北市  709374  1165888  252486
# 7   　桃園市  369013   547573  156518
# 8   　臺中市  430005   793281  218810
# 9   　臺南市  219196   670608  103432
# 10  　高雄市  391823   955168  159765
# 11  　新竹縣   94603   114023   59510
# 12  　苗栗縣  107779   130461   48788
# 13  　彰化縣  193117   378736   98807
# 14  　南投縣   83604   136104   40868
# 15  　雲林縣   86047   218842   40236
# 16  　嘉義縣   65425   182913   31469
# 17  　屏東縣  121291   285297   42768
# 18  　宜蘭縣   59216   144798   29288
# 19  　花蓮縣   73894    57198   23751
# 20  　臺東縣   43581    37517   16565
# 21  　澎湖縣   12564    21658    8401
# 22  　基隆市   68357    93402   31955
# 23  　新竹市   71771   113386   36198
# 24  　嘉義市   38822    83143   16926
# 25  　金門縣   24327     6626    5852
# 26  　連江縣    3065      739     664

# %%
#更改欄位資料類型
df.dtypes
df['朱立倫']=df['朱立倫'].astype(np.int64)
df['蔡英文']=df['蔡英文'].astype(np.int64)
df['宋楚瑜']=df['宋楚瑜'].astype(np.int64)
df.dtypes
# Out:
# 縣市     object
# 朱立倫     int64
# 蔡英文     int64
# 宋楚瑜     int64
# dtype: object

# %%
df=df.reset_index(drop=True)
df
# Out:
#       縣市     朱立倫      蔡英文     宋楚瑜
# 0   　臺北市  546491   757383  153804
# 1   　新北市  709374  1165888  252486
# 2   　桃園市  369013   547573  156518
# 3   　臺中市  430005   793281  218810
# 4   　臺南市  219196   670608  103432
# 5   　高雄市  391823   955168  159765
# 6   　新竹縣   94603   114023   59510
# 7   　苗栗縣  107779   130461   48788
# 8   　彰化縣  193117   378736   98807
# 9   　南投縣   83604   136104   40868
# 10  　雲林縣   86047   218842   40236
# 11  　嘉義縣   65425   182913   31469
# 12  　屏東縣  121291   285297   42768
# 13  　宜蘭縣   59216   144798   29288
# 14  　花蓮縣   73894    57198   23751
# 15  　臺東縣   43581    37517   16565
# 16  　澎湖縣   12564    21658    8401
# 17  　基隆市   68357    93402   31955
# 18  　新竹市   71771   113386   36198
# 19  　嘉義市   38822    83143   16926
# 20  　金門縣   24327     6626    5852
# 21  　連江縣    3065      739     664

# %%
df = df.set_index('縣市')
df
# Out:
#          朱立倫      蔡英文     宋楚瑜
# 縣市
# 　臺北市  546491   757383  153804
# 　新北市  709374  1165888  252486
# 　桃園市  369013   547573  156518
# 　臺中市  430005   793281  218810
# 　臺南市  219196   670608  103432
# 　高雄市  391823   955168  159765
# 　新竹縣   94603   114023   59510
# 　苗栗縣  107779   130461   48788
# 　彰化縣  193117   378736   98807
# 　南投縣   83604   136104   40868
# 　雲林縣   86047   218842   40236
# 　嘉義縣   65425   182913   31469
# 　屏東縣  121291   285297   42768
# 　宜蘭縣   59216   144798   29288
# 　花蓮縣   73894    57198   23751
# 　臺東縣   43581    37517   16565
# 　澎湖縣   12564    21658    8401
# 　基隆市   68357    93402   31955
# 　新竹市   71771   113386   36198
# 　嘉義市   38822    83143   16926
# 　金門縣   24327     6626    5852
# 　連江縣    3065      739     664

# %%
df.columns.name = '總統候選人'
df
# Out:
# 總統候選人     朱立倫      蔡英文     宋楚瑜
# 縣市
# 　臺北市   546491   757383  153804
# 　新北市   709374  1165888  252486
# 　桃園市   369013   547573  156518
# 　臺中市   430005   793281  218810
# 　臺南市   219196   670608  103432
# 　高雄市   391823   955168  159765
# 　新竹縣    94603   114023   59510
# 　苗栗縣   107779   130461   48788
# 　彰化縣   193117   378736   98807
# 　南投縣    83604   136104   40868
# 　雲林縣    86047   218842   40236
# 　嘉義縣    65425   182913   31469
# 　屏東縣   121291   285297   42768
# 　宜蘭縣    59216   144798   29288
# 　花蓮縣    73894    57198   23751
# 　臺東縣    43581    37517   16565
# 　澎湖縣    12564    21658    8401
# 　基隆市    68357    93402   31955
# 　新竹市    71771   113386   36198
# 　嘉義市    38822    83143   16926
# 　金門縣    24327     6626    5852
# 　連江縣     3065      739     664

# %%
dfSum = df.sum()
dfSum
# Out:
# 總統候選人
# 朱立倫    3813365
# 蔡英文    6894744
# 宋楚瑜    1576861
# dtype: int64

# %%
figure1,ax1=plt.subplots()
dfSum.plot(ax=ax1,kind='bar',color=['b','g','orange'])
ax1.set_xticklabels(dfSum.index,fontproperties = font,rotation=30)
ax1.set_xlabel('總統候選人',fontproperties = font)
ax1.set_yticklabels(['0','1佰萬','2佰萬','3佰萬','4佰萬','5佰萬','6佰萬','7佰萬'],fontproperties = font)
ax1.legend(['朱立倫','蔡英文','宋楚瑜'],prop=font)
for p in ax1.patches:
    width, height= p.get_width() , p.get_height()
    x,y = p.get_xy()
    ax1.annotate(f'{height}票',(x+width/5,y+height+100000),fontproperties=font)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-13-2b7ffb4dd03a>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels(['0','1佰萬','2佰萬','3佰萬','4佰萬','5佰萬','6佰萬','7佰萬'],fontproperties = font)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-2b7ffb4dd03a> in <module>
#       4 ax1.set_xlabel('總統候選人',fontproperties = font)
#       5 ax1.set_yticklabels(['0','1佰萬','2佰萬','3佰萬','4佰萬','5佰萬','6佰萬','7佰萬'],fontproperties = font)
# ----> 6 ax1.legend(['朱立倫','蔡英文','宋楚瑜'],prop=font,nrow=3)
#       7 for p in ax1.patches:
#       8     width, height= p.get_width() , p.get_height()
#
# ~/Documents/virtualenv01/venv01/lib/python3.8/site-packages/matplotlib/axes/_axes.py in legend(self, *args, **kwargs)
#     288         if len(extra_args):
# ...

# %%
dfPercent = dfSum / dfSum.sum()
dfPercent
# Out:
# 總統候選人
# 朱立倫    0.310409
# 蔡英文    0.561234
# 宋楚瑜    0.128357
# dtype: float64

# %%
figure2, ax2 = plt.subplots()
dfPercent.plot(ax=ax2,kind='barh',color=['b','g','orange'])
ax2.set_title('2016得票率',fontproperties=font)
ax2.set_ylabel('總統候選人',fontproperties=font)
ax2.set_yticklabels(['朱立倫','蔡英文','宋楚瑜'],fontproperties=font)
for p in ax2.patches:
    width, height = p.get_width(), p.get_height()
    print(width)
    x, y = p.get_xy()
    ax2.annotate('{:.0%}'.format(width), (width+0.01, y+height/2))
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.3104089794277072
# 0.5612340933677493
# 0.12835692720454345
