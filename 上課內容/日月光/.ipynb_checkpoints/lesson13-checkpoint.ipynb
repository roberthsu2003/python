# %%
import requests
response = requests.post('https://httpbin.org/post',{'id':'A007','auth':'1234567890'})

# %%
response.url
# Out:
# 'https://httpbin.org/post'

# %%
responseGet = requests.get('https://httpbin.org/get',{'id':'A007','auth':'1234567890'})
responseGet.url
# Out:
# 'https://httpbin.org/get?id=A007&auth=1234567890'

# %%
imageURL = "https://res.klook.com/image/upload/c_crop,h_668,w_1687,x_0,y_0/c_fill,w_960,h_460,f_auto/w_80,x_15,y_15,g_south_west,l_klook_water/activities/orq6ulmzbtxshu1yb2dp.jpg"
response = requests.get(imageURL)
if response.status_code == 200:
    print('下載成功')
    print(response.content)
else:
    print('下載失敗')
# Out:
# 下載成功
# ...

# %%
from io import BytesIO
from PIL import Image
myImage=Image.open(BytesIO(response.content))
myImage.save('happyGirs.jpg')

# %%
response = requests.get('https://api.github.com/events')
response.json()
# Out:
# [{'id': '15589833081',
#   'type': 'PushEvent',
#   'actor': {'id': 9348255,
#    'login': 'nguyenanhung',
#    'display_login': 'nguyenanhung',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nguyenanhung',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9348255?'},
#   'repo': {'id': 151945101,
#    'name': 'nguyenanhung/my-debug',
#    'url': 'https://api.github.com/repos/nguyenanhung/my-debug'},
#   'payload': {'push_id': 6734696420,
#    'size': 29,
#    'distinct_size': 0,
#    'ref': 'refs/heads/develop',
#    'head': 'f2dc798100ccb95e6a8f5575cb7cc5a7a0160540',
#    'before': '5ff3781b76a1b11150284b3ab7fbb204d0c50739',
#    'commits': [{'sha': '0157bf08257148eb13b9b8a5b1b7e4c890fc6723',
#      'author': {'email': 'dev@nguyenanhung.com', 'name': 'Hung Nguyen'},
#      'message': 'Merge pull request #1 from nguyenanhung/develop\n\nDevelop',
#      'distinct': False,
# ...

# %%
downloadURL = 'https://www.post.gov.tw/post/internet/Templates/getOpenDataFile.jsp?vkey=85422E4D-6133-4404-851E-08EC2077A162'
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36'}
response = requests.get(downloadURL,headers = headers)
print(response.status_code)
with open('全台灣郵局.csv','wb') as fd:
    for chunk in response.iter_content(chunk_size=128):
        fd.write(chunk)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~/Documents/virtualenv01/env01/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/Documents/virtualenv01/env01/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ...
