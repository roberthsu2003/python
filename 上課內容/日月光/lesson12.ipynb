# %%
import requests
urlString = "https://flask-robert.herokuapp.com/youbike/"
response = requests.get(urlString)

# %%
help(response)

# %%
if response.ok:
    print(response.text)
else:
    print('下載失敗')
# Out:
# {"areas":["南港區","文山區","大同區","內湖區","信義區","中山區","中正區","萬華區","大安區","松山區","北投區","士林區"]}

# %%
response.ok
# Out:
# True

# %%
response.content
# Out:
# b'{"areas":["\xe5\x8d\x97\xe6\xb8\xaf\xe5\x8d\x80","\xe6\x96\x87\xe5\xb1\xb1\xe5\x8d\x80","\xe5\xa4\xa7\xe5\x90\x8c\xe5\x8d\x80","\xe5\x85\xa7\xe6\xb9\x96\xe5\x8d\x80","\xe4\xbf\xa1\xe7\xbe\xa9\xe5\x8d\x80","\xe4\xb8\xad\xe5\xb1\xb1\xe5\x8d\x80","\xe4\xb8\xad\xe6\xad\xa3\xe5\x8d\x80","\xe8\x90\xac\xe8\x8f\xaf\xe5\x8d\x80","\xe5\xa4\xa7\xe5\xae\x89\xe5\x8d\x80","\xe6\x9d\xbe\xe5\xb1\xb1\xe5\x8d\x80","\xe5\x8c\x97\xe6\x8a\x95\xe5\x8d\x80","\xe5\xa3\xab\xe6\x9e\x97\xe5\x8d\x80"]}\n'

# %%
import json
areas = json.loads(response.text)
areaList = areas['areas']
for area in areaList:
    print(area)
# Out:
# 南港區
# 文山區
# 大同區
# 內湖區
# 信義區
# 中山區
# 中正區
# 萬華區
# 大安區
# 松山區
# 北投區
# 士林區

# %%
listString = ','.join(areaList) 
codes=input(f'請輸入行政區域名稱[{listString}]:')
# Out:
# 請輸入行政區域名稱[南港區,文山區,大同區,內湖區,信義區,中山區,中正區,萬華區,大安區,松山區,北投區,士林區]:文山區

# %%
codes
# Out:
# '文山區'

# %%
codesUrlString = 'https://flask-robert.herokuapp.com/youbike/'+codes
response1 = requests.get(codesUrlString)
if response1.ok :
    print(response1.text)
else:
    print('下載錯誤')
# Out:
# {"data":[{"ar":"師大公館校區校門口(汀州路側)","bemp":"16","lat":"25.007528","lng":"121.537188 ","mday":"20210318132719","sbi":"26","sna":"師範大學公館校區","tot":"42"},{"ar":"興隆路二段123巷/興隆路二段(西北側)","bemp":"19","lat":"24.999837","lng":"121.547778","mday":"20210318132738","sbi":"9","sna":"興豐公園","tot":"34"},{"ar":"羅斯福路六段/景中街交叉口(東北側)(鄰近景美夜市)","bemp":"51","lat":"24.993254","lng":"121.541059","mday":"20210318132730","sbi":"1","sna":"捷運景美站","tot":"52"},{"ar":"羅斯福路六段/景隆街交叉口(東南側)","bemp":"13","lat":"24.999378","lng":"121.540197","mday":"20210318132743","sbi":"29","sna":"羅斯福景隆街口","tot":"42"},{"ar":"萬盛街/興隆路一段(西北側)","bemp":"36","lat":"25.004023","lng":"121.54074","mday":"20210318132720","sbi":"2","sna":"台北花木批發市場","tot":"38"},{"ar":"木柵路三段220號前","bemp":"18","lat":"24.989902","lng":"121.569984","mday":"20210318132719","sbi":"18","sna":"文山行政中心","tot":"36"},{"ar":"木柵路四段82巷18號前(捷運橋樑下)","bemp":"30","lat":"24.997996","lng":"121.57444","mday":"20210318132727","sbi":"22","sna":"捷運木柵站","tot":"52"},{"ar":"新光路二段28號前(鄰近台北市立動物園(木柵動
# ...

# %%
pythonData = json.loads(response1.text)
dataList=pythonData['data']
print(f'總站數:{len(dataList)}')
for data in dataList:
    print(f"名稱:{data['sna']}")
    print(f"總數:{data['tot']}")
    print(f"可借:{data['sbi']}")
    print(f"可還:{data['bemp']}")
    print("==================")
# Out:
# 總站數:27
# 名稱:師範大學公館校區
# 總數:42
# 可借:26
# 可還:16
# ...
# 名稱:興豐公園
# 總數:34
# 可借:9
# 可還:19
# ...
# 名稱:捷運景美站
# 總數:52
# 可借:1
# 可還:51
# ...
# 名稱:羅斯福景隆街口
# 總數:42
# 可借:29
# 可還:13
# ...
# 名稱:台北花木批發市場
# 總數:38
# 可借:2
# 可還:36
# ...
# 名稱:文山行政中心
# 總數:36
# 可借:18
# 可還:18
# ...
# 名稱:捷運木柵站
# 總數:52
# 可借:22
# 可還:30
# ...
# 名稱:捷運動物園站(2號出口)
# 總數:72
# 可借:8
# 可還:61
# ...
# 名稱:國立政治大學
# 總數:58
# 可借:23
# 可還:34
# ...
# 名稱:考試院
# 總數:34
# 可借:22
# 可還:12
# ...
# 名稱:臺北市立景美女中
# 總數:34
# 可借:8
# 可還:26
# ...
# 名稱:文山運動中心
# 總數:38
# 可借:2
# 可還:36
# ...
# 名稱:木柵光輝路口
# 總數:24
# 可借:2
# 可還:22
# ...
# 名稱:捷運辛亥站
# 總數:32
# 可借:10
# 可還:22
# ...
# 名稱:捷運萬芳社區站
# 總數:32
# 可借:5
# 可還:25
# ...
# 名稱:文山第二行政中心
# 總數:38
# 可借:11
# 可還:26
# ...
# 名稱:木柵公園
# 總數:34
# 可借:21
# 可還:13
# ...
# 名稱:永安藝文館-表演36房
# 總數:28
# 可借:2
# 可還:26
# ...
# 名稱:忠順區民活動中心
# 總數:32
# 可借:3
# 可還:28
# ...
# 名稱:萬和二號公園
# 總數:32
# 可借:5
# 可還:27
# ...
# 名稱:捷運萬隆站(1號出口)
# 總數:38
# 可借:8
# 可還:30
# ...
# 名稱:景文中學
# 總數:32
# 可借:15
# 可還:17
# ...
# 名稱:世新大學
# 總數:34
# 可借:12
# 可還:22
# ...
# 名稱:一壽橋
# 總數:26
# 可借:4
# 可還:22
# ...
# 名稱:和興路26巷口
# 總數:40
# 可借:3
# 可還:37
# ...
# 名稱:景華街128巷口
# 總數:24
# 可借:2
# 可還:21
# ...
# 名稱:景仁公園
# 總數:30
# 可借:17
# 可還:13
# ...
