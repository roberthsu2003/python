# %%
#建立空set
empty_set = set()
empty_set
# Out:
# set()

# %%
even_numbers = {0, 2, 4, 6, 8, 10, 2, 4, 6, 8, 10}
even_numbers
# Out:
# {0, 2, 4, 6, 8, 10}

# %%
even_numbers.add(12)
even_numbers
# Out:
# {0, 2, 4, 6, 8, 10, 12}

# %%
list(even_numbers)
# Out:
# [0, 2, 4, 6, 8, 10, 12]

# %%
import random
lot = set()
while(len(lot) < 7):
    lot.add(random.randint(1,49))
lot_list = list(lot)
specialNum = lot_list.pop()

for item in lot_list:
    print(item, end=' ')
print(f'特別號:{specialNum}')
# Out:
# 1 43 12 13 14 47 特別號:27

# %%
#自訂的function
def big_lot():
    lot = set()
    
    while(len(lot) < 7):
        lot.add(random.randint(1,49))
    lot_list = list(lot)
    specialNum = lot_list.pop()

    for item in lot_list:
        print(item, end=' ')
    print(f'特別號:{specialNum}')
    print("============")
    
    
group = int(input('請輸入大樂透電腦選號組數:'))
for _ in range(group):
    big_lot()
# Out:
# 請輸入大樂透電腦選號組數:5
# 32 36 8 11 22 24 特別號:27
# ============
# 4 37 9 43 44 14 特別號:28
# ============
# 32 36 5 8 15 19 特別號:29
# ============
# 37 38 7 42 15 49 特別號:26
# ============
# 2 3 36 37 12 19 特別號:26
# ============

# %%
import random
list1 = [random.randint(1,100) for _ in range(20)]
list1
# Out:
# [99, 95, 74, 98, 9, 94, 16, 3, 42, 54, 56, 64, 40, 45, 25, 39, 70, 8, 29, 58]

# %%
#list comprehension

list2 = [[random.randint(60,100) for _ in range(5)] for _ in range(50)]
list2
# Out:
# [[63, 79, 72, 78, 88],
#  [69, 69, 92, 98, 94],
#  [90, 67, 96, 94, 68],
#  [69, 84, 68, 60, 81],
#  [69, 69, 87, 78, 89],
#  [96, 78, 93, 80, 95],
#  [94, 81, 99, 100, 79],
#  [69, 65, 76, 92, 71],
#  [97, 100, 62, 67, 94],
#  [69, 87, 84, 63, 85],
#  [67, 98, 90, 88, 81],
#  [73, 89, 72, 74, 94],
#  [77, 89, 81, 71, 78],
#  [98, 74, 85, 77, 73],
#  [87, 93, 69, 69, 71],
#  [84, 79, 85, 93, 70],
#  [68, 93, 83, 71, 99],
#  [100, 66, 90, 76, 96],
#  [70, 99, 100, 91, 90],
#  [69, 97, 86, 75, 65],
#  [98, 88, 79, 68, 78],
#  [82, 96, 69, 84, 60],
#  [79, 90, 70, 65, 98],
#  [61, 60, 72, 69, 73],
#  [76, 92, 100, 99, 75],
#  [76, 93, 92, 92, 61],
#  [79, 97, 99, 92, 73],
#  [63, 85, 63, 90, 98],
#  [91, 77, 92, 76, 97],
#  [94, 98, 66, 83, 78],
#  [75, 91, 89, 67, 82],
#  [60, 66, 96, 78, 85],
#  [83, 75, 61, 97, 89],
#  [83, 64, 77, 76, 82],
#  [68, 66, 77, 75, 60],
#  [97, 87, 71, 69, 87],
#  [67, 76, 68, 65, 76],
#  [80, 67, 60, 65, 96],
#  [60, 82, 66, 82, 92],
#  [81, 75, 89, 90, 80],
#  [100, 67, 81, 76, 77],
#  [95, 96, 86, 100, 69],
#  [84, 69, 94, 88, 98],
#  [98, 60, 65, 88, 74],
#  [86, 92, 68, 85, 69],
#  [72, 72, 93, 63, 63],
#  [96, 88, 81, 69, 66],
#  [73, 60, 73, 100, 88],
#  [100, 66, 95, 71, 69],
#  [84, 83, 68, 73, 67]]

# %%
#list comprehension
[{
    '國文':random.randint(60,100),
    '英文':random.randint(60,100),
    '數學':random.randint(60,100),
    '地理':random.randint(60,100),
    '自然':random.randint(60,100),
    
 } for _ in range(50)]
# Out:
# [{'國文': 75, '英文': 66, '數學': 91, '地理': 100, '自然': 72},
#  {'國文': 84, '英文': 67, '數學': 97, '地理': 81, '自然': 91},
#  {'國文': 86, '英文': 81, '數學': 95, '地理': 71, '自然': 98},
#  {'國文': 84, '英文': 60, '數學': 79, '地理': 100, '自然': 90},
#  {'國文': 100, '英文': 94, '數學': 61, '地理': 87, '自然': 80},
#  {'國文': 82, '英文': 92, '數學': 98, '地理': 93, '自然': 72},
#  {'國文': 99, '英文': 75, '數學': 91, '地理': 90, '自然': 83},
#  {'國文': 84, '英文': 71, '數學': 99, '地理': 67, '自然': 94},
#  {'國文': 65, '英文': 85, '數學': 91, '地理': 100, '自然': 89},
#  {'國文': 72, '英文': 70, '數學': 69, '地理': 95, '自然': 95},
#  {'國文': 94, '英文': 76, '數學': 92, '地理': 98, '自然': 66},
#  {'國文': 71, '英文': 96, '數學': 77, '地理': 95, '自然': 81},
#  {'國文': 61, '英文': 67, '數學': 71, '地理': 70, '自然': 100},
#  {'國文': 84, '英文': 86, '數學': 98, '地理': 97, '自然': 92},
#  {'國文': 74, '英文': 85, '數學': 78, '地理': 62, '自然': 62},
#  {'國文': 97, '英文': 65, '數學': 64, '地理': 75, '自然': 91},
#  {'國文': 93, '英文': 76, '數學': 92, '地理': 77, '自然': 90},
#  {'國文': 100, '英文': 96, '數學': 83, '地理': 76, '自然': 87},
#  {'國文': 74, '英文': 74, '數學': 60, '地理': 63, '自然': 87},
#  {'國文': 83, '英文': 60, '數學': 82, '地理': 73, '自然': 92},
#  {'國文': 89, '英文': 84, '數學': 87, '地理': 100, '自然': 72},
#  {'國文': 67, '英文': 66, '數學': 68, '地理': 62, '自然': 84},
#  {'國文': 97, '英文': 83, '數學': 75, '地理': 83, '自然': 92},
#  {'國文': 92, '英文': 85, '數學': 99, '地理': 63, '自然': 89},
#  {'國文': 83, '英文': 86, '數學': 75, '地理': 91, '自然': 83},
#  {'國文': 62, '英文': 97, '數學': 77, '地理': 76, '自然': 93},
#  {'國文': 76, '英文': 62, '數學': 91, '地理': 87, '自然': 97},
#  {'國文': 90, '英文': 68, '數學': 61, '地理': 63, '自然': 82},
#  {'國文': 73, '英文': 96, '數學': 77, '地理': 96, '自然': 73},
#  {'國文': 64, '英文': 75, '數學': 98, '地理': 69, '自然': 84},
#  {'國文': 87, '英文': 82, '數學': 69, '地理': 88, '自然': 79},
#  {'國文': 95, '英文': 64, '數學': 90, '地理': 100, '自然': 98},
#  {'國文': 98, '英文': 89, '數學': 73, '地理': 84, '自然': 60},
#  {'國文': 97, '英文': 93, '數學': 90, '地理': 90, '自然': 91},
#  {'國文': 92, '英文': 90, '數學': 64, '地理': 98, '自然': 61},
#  {'國文': 61, '英文': 83, '數學': 60, '地理': 83, '自然': 88},
#  {'國文': 65, '英文': 84, '數學': 100, '地理': 67, '自然': 75},
#  {'國文': 83, '英文': 86, '數學': 94, '地理': 99, '自然': 95},
#  {'國文': 66, '英文': 73, '數學': 86, '地理': 91, '自然': 85},
#  {'國文': 76, '英文': 87, '數學': 90, '地理': 62, '自然': 94},
#  {'國文': 100, '英文': 72, '數學': 64, '地理': 76, '自然': 75},
#  {'國文': 76, '英文': 62, '數學': 97, '地理': 61, '自然': 88},
#  {'國文': 100, '英文': 91, '數學': 72, '地理': 91, '自然': 95},
#  {'國文': 61, '英文': 68, '數學': 67, '地理': 83, '自然': 84},
#  {'國文': 96, '英文': 91, '數學': 79, '地理': 86, '自然': 83},
#  {'國文': 86, '英文': 79, '數學': 87, '地理': 84, '自然': 84},
#  {'國文': 67, '英文': 86, '數學': 72, '地理': 78, '自然': 80},
#  {'國文': 96, '英文': 68, '數學': 99, '地理': 83, '自然': 82},
#  {'國文': 76, '英文': 100, '數學': 80, '地理': 62, '自然': 61},
#  {'國文': 65, '英文': 60, '數學': 71, '地理': 92, '自然': 60}]
