# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[4,5,6])

# %%
#建立figure
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(8,5),facecolor="white")
axes = figure.add_subplot(1,1,1)
x = [0, 1, 10]
y = [3, 4, 5]
axes.plot(x,y)
plt.show()

# %%
figure = plt.figure(figsize=(8,5),dpi=220,facecolor="#cccccc")
axes1 = figure.add_subplot(1,3,1)
axes2 = figure.add_subplot(1,3,2)
axes3 = figure.add_subplot(1,3,3)

axes1.set_title("chart 1")
axes2.set_title("chart 2")
axes3.set_title("chart 3")

plt.show()

# %%
fig1 = plt.figure()
axes1 = fig1.add_subplot(1,1,1)
x = [0,1,2]
y= [3,4,1]
axes1.plot(x,y)

fig2 = plt.figure()
axes2 = fig2.add_subplot(1,1,1)
x1 = [2,3,6]
y1 = [2,1,2]
axes2.plot(x1,y1)

plt.show()

# %%
import matplotlib.pyplot as plt

student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85}
student2 = {'chinese':92, 'english':72, 'math':87, 'history':61, 'discover':90}

subject = list(student1.keys())
student1_score = list(student1.values())
student2_score = list(student2.values())

figure = plt.figure(figsize=(8,5),dpi=220,facecolor='#cccccc')
axes = figure.add_subplot()
axes.plot(subject,student1_score,'m--D')
axes.plot(subject,student2_score,'r-.o')

plt.show()

# %%
#中文的解決方法
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)
#window font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)

subject = ['國文','英文','數學','歷史','探索']
figure = plt.figure(figsize=(8,5),dpi=220,facecolor='#cccccc')
axes = figure.add_subplot()
axes.plot(subject,student1_score,'m--D')
axes.plot(subject,student2_score,'r-.o')
axes.set_xticklabels(subject,fontproperties=font)
axes.set_title("學生1和學生2分數比較表",fontproperties=font)
axes.legend(['學生1','學生2'],prop=font)
for i in range(len(subject)):
    axes.annotate(str(student1_score[i]),(i,student1_score[i]+0.8),fontproperties=font)
    axes.annotate(str(student2_score[i]),(i,student2_score[i]+0.8),fontproperties=font)

axes.annotate("註解:\n這只是一個範例",(3,85),fontproperties=font)
print(axes.axis())
axes.axis(xmin=-0.5,xmax=5,ymin=58,ymax=95)
plt.show()

# %%
#中文的解決方法
#顯示局部範圍
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)
#window font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)

subject = ['國文','英文','數學','歷史','探索']
figure = plt.figure(figsize=(8,5),dpi=220,facecolor='#cccccc')
axes = figure.add_subplot()
axes.plot(subject,student1_score,'m--D')
axes.plot(subject,student2_score,'r-.o')
axes.set_xticklabels(subject,fontproperties=font)
axes.set_title("學生1和學生2分數比較表",fontproperties=font)
axes.legend(['學生1','學生2'],prop=font)
for i in range(len(subject)):
    axes.annotate(str(student1_score[i]),(i,student1_score[i]+0.8),fontproperties=font)
    axes.annotate(str(student2_score[i]),(i,student2_score[i]+0.8),fontproperties=font)

axes.annotate("註解:\n這只是一個範例",(3,85),fontproperties=font)
axes.axis(xmin=-0.5,xmax=5,ymin=58,ymax=95)
axes.set_xlim(1.4,2.5)
plt.show()
# Out:
# /var/folders/by/68nnsq553f59kbs1v470m4k40000gp/T/ipykernel_2407/767794836.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes.set_xticklabels(subject,fontproperties=font)
