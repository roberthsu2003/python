# %%
import matplotlib.pyplot as plt

#index = list(range(5))
index = [3, 4, 5, 6, 7]
values = [5000, 6000, 7000, 8000, 9000]
figure = plt.figure()
axes = figure.add_subplot()
axes.bar(index, values)
print(axes.axis())
plt.show()
# Out:
# (2.3600000000000003, 7.64, 0.0, 9450.0)
