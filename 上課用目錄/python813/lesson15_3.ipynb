# %%
import pandas as pd
#list建立Series
obj1 = pd.Series([80, 90, 75, 65],
                index=['chinese','english','math','history'])
obj1
# Out:
# chinese    80
# english    90
# math       75
# history    65
# dtype: int64

# %%
obj2 = pd.Series({'台北':35000, '桃園':71000, '台中':16000, '高雄':5000})
obj2
# Out:
# 台北    35000
# 桃園    71000
# 台中    16000
# 高雄     5000
# dtype: int64

# %%
obj3 = pd.Series({'Taipei':35000, 'Taoyuan':71000, 'Taichung':16000, 'Kaohsiung':5000})
obj3
# Out:
# Taipei       35000
# Taoyuan      71000
# Taichung     16000
# Kaohsiung     5000
# dtype: int64

# %%
obj3.index
# Out:
# Index(['Taipei', 'Taoyuan', 'Taichung', 'Kaohsiung'], dtype='object')

# %%
obj3.values
# Out:
# array([35000, 71000, 16000,  5000])

# %%
import matplotlib.pyplot as plt

figure, axes = plt.subplots()
axes.bar(obj3.index,obj3.values)
plt.show()
