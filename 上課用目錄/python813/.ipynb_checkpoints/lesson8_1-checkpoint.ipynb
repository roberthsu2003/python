# %%
#台北市youbike2.0及時資料
#https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json
import requests
youbike_taipei = "https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 #台北市youbike2.0及時資料
#       2 #https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json
# ----> 3 import requests
#       4 youbike_taipei = "https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json"
#
# ModuleNotFoundError: No module named 'requests'
