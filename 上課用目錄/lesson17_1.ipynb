# %%
import pandas as pd
s1 = pd.Series(range(4), index=['d', 'a', 'b', 'c'])
s1
# Out:
# d    0
# a    1
# b    2
# c    3
# dtype: int64

# %%
s1.sort_index()
s1.sort_index(ascending=False)
# Out:
# d    0
# c    3
# b    2
# a    1
# dtype: int64

# %%
# dataFrame 排序
import numpy as np

dataFrame1 = pd.DataFrame(np.arange(8).reshape((2,4)),
             index=["three", "one"],
             columns=["d", "a", "b", "c"])
dataFrame1.sort_index(axis=1)
dataFrame1.sort_index(axis=1,ascending=False)
dataFrame1.sort_values(by='d',ascending=False)
dataFrame1.sort_values(by='one',axis=1,ascending=False)
# Out:
#        c  b  a  d
# three  3  2  1  0
# one    7  6  5  4

# %%
dataFrame1 = pd.read_csv('學生成績表1.csv')
dataFrame1.index = dataFrame1['姓名']
dataFrame2 = dataFrame1[['國文','英文','數學', '地理', '歷史']]
dataFrame2
# Out:
#       國文   英文  數學   地理   歷史
# 姓名
# 葉志峰   67   61  73   82   64
# 彭茹靖   87   93  53   66   58
# 吳志宣   79   74  70   62   55
# 黃詩妃   68   97  76   93   86
# 陳向愛  100   96  56   51   90
# 張凱妮   93   93  55   60   59
# 張嘉韋   62   95  71   56   79
# 黃嘉琪   58   60  89   69   76
# 郭淑真   67   78  64   68   60
# 林佳光   55   85  98   97   77
# 高智超   65   65  81   69   79
# 張牧聿   58   52  66   61   89
# 溫重意   97   88  68   53   87
# 馬彥文   59   71  85   53   65
# 黃健發   55   84  98   86   87
# 陳淑娟   58  100  90   80   71
# 謝貞妃   62   67  98   98   81
# 李慶亮   84   98  97   89   53
# 吳淑惠   84   87  96   69   73
# 楊綺芬   95   85  59   50   57
# 張俊傑   71   78  66   94   75
# 林珍旺   53   82  72   79  100
# 郎慧萍   65   51  50   62   83
# 趙偉銘   86   82  58   56   71
# 游倫城   71   90  60   71   81
# 吳麗卿   58   94  55   72   72
# 艾巧夫  100   68  61   61   66
# 王泓泰   56   55  84   72   66
# 鄭奇翰   80   57  85   56   63
# 戴萱能   70   97  70   50  100
# 程玫靖   73   88  90   99   84
# 謝哲維   68   66  73   76   74
# 張伊映   98   64  82   80   81
# 吳欣書   95   92  86   91   55
# 藍哲嘉   68   74  91   73   85
# 林向鈺   72   80  69   53   55
# 陳淑娟   95   51  60   93   88
# 王雅慧   50   76  97   57   79
# 劉嘉泰   96   57  55   71   95
# 陳倩妮   61   71  95   73   97
# 藍哲嘉   84   51  99  100   65
# 呂傑宣   85   52  77   64   82
# 鍾俞禎   58   97  50   85   83
# 溫重意   57   50  58   91   57
# 鄭奇翰   73   66  75   62   87
# 魏秋萍   65   91  64   72   79
# 魏秋萍   79  100  71   92   64
# 李政成   66   64  95   60   57
# 張明惟   58   61  60   60   93
# 王雅慧   77   67  79   61   55

# %%
sum_s = dataFrame2.sum(axis=1)
mean_s = dataFrame2.mean(axis=1)
dataFrame2['總分'] = sum_s
dataFrame2['平均'] = mean_s
dataFrame2
# Out:
#       國文   英文  數學   地理   歷史   總分    平均
# 姓名
# 葉志峰   67   61  73   82   64  347  69.4
# 彭茹靖   87   93  53   66   58  357  71.4
# 吳志宣   79   74  70   62   55  340  68.0
# 黃詩妃   68   97  76   93   86  420  84.0
# 陳向愛  100   96  56   51   90  393  78.6
# 張凱妮   93   93  55   60   59  360  72.0
# 張嘉韋   62   95  71   56   79  363  72.6
# 黃嘉琪   58   60  89   69   76  352  70.4
# 郭淑真   67   78  64   68   60  337  67.4
# 林佳光   55   85  98   97   77  412  82.4
# 高智超   65   65  81   69   79  359  71.8
# 張牧聿   58   52  66   61   89  326  65.2
# 溫重意   97   88  68   53   87  393  78.6
# 馬彥文   59   71  85   53   65  333  66.6
# 黃健發   55   84  98   86   87  410  82.0
# 陳淑娟   58  100  90   80   71  399  79.8
# 謝貞妃   62   67  98   98   81  406  81.2
# 李慶亮   84   98  97   89   53  421  84.2
# 吳淑惠   84   87  96   69   73  409  81.8
# 楊綺芬   95   85  59   50   57  346  69.2
# 張俊傑   71   78  66   94   75  384  76.8
# 林珍旺   53   82  72   79  100  386  77.2
# 郎慧萍   65   51  50   62   83  311  62.2
# 趙偉銘   86   82  58   56   71  353  70.6
# 游倫城   71   90  60   71   81  373  74.6
# 吳麗卿   58   94  55   72   72  351  70.2
# 艾巧夫  100   68  61   61   66  356  71.2
# 王泓泰   56   55  84   72   66  333  66.6
# 鄭奇翰   80   57  85   56   63  341  68.2
# 戴萱能   70   97  70   50  100  387  77.4
# 程玫靖   73   88  90   99   84  434  86.8
# 謝哲維   68   66  73   76   74  357  71.4
# 張伊映   98   64  82   80   81  405  81.0
# 吳欣書   95   92  86   91   55  419  83.8
# 藍哲嘉   68   74  91   73   85  391  78.2
# 林向鈺   72   80  69   53   55  329  65.8
# 陳淑娟   95   51  60   93   88  387  77.4
# 王雅慧   50   76  97   57   79  359  71.8
# 劉嘉泰   96   57  55   71   95  374  74.8
# 陳倩妮   61   71  95   73   97  397  79.4
# 藍哲嘉   84   51  99  100   65  399  79.8
# 呂傑宣   85   52  77   64   82  360  72.0
# 鍾俞禎   58   97  50   85   83  373  74.6
# 溫重意   57   50  58   91   57  313  62.6
# 鄭奇翰   73   66  75   62   87  363  72.6
# 魏秋萍   65   91  64   72   79  371  74.2
# 魏秋萍   79  100  71   92   64  406  81.2
# 李政成   66   64  95   60   57  342  68.4
# 張明惟   58   61  60   60   93  332  66.4
# 王雅慧   77   67  79   61   55  339  67.8

# %%
#全班前5名
dataFrame2.sort_values(by='總分',ascending=False).iloc[:5]
# Out:
#      國文  英文  數學  地理  歷史   總分    平均
# 姓名
# 程玫靖  73  88  90  99  84  434  86.8
# 李慶亮  84  98  97  89  53  421  84.2
# 黃詩妃  68  97  76  93  86  420  84.0
# 吳欣書  95  92  86  91  55  419  83.8
# 林佳光  55  85  98  97  77  412  82.4

# %%
#全班前後名
dataFrame2.sort_values(by='總分').iloc[:5]
# Out:
#      國文  英文  數學  地理  歷史   總分    平均
# 姓名
# 郎慧萍  65  51  50  62  83  311  62.2
# 溫重意  57  50  58  91  57  313  62.6
# 張牧聿  58  52  66  61  89  326  65.2
# 林向鈺  72  80  69  53  55  329  65.8
# 張明惟  58  61  60  60  93  332  66.4
