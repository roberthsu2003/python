# %%
import pandas as pd
xlsx_file = pd.ExcelFile('covid19_vac_hosp.xlsx')
df_all= pd.read_excel(xlsx_file,'工作表1')
df_all
# Out:
#              院所名稱   縣市   鄉鎮           疫苗種類名稱      醫事機構代碼                 地址  \
# 0            仁佑診所  宜蘭縣  三星鄉      AstraZeneca  3534101064     宜蘭縣三星鄉三星路5段67號
# 1       宜蘭縣大同鄉衛生所  宜蘭縣  大同鄉      AstraZeneca  2334110013     宜蘭縣大同鄉崙埤村朝陽40號
# 2       宜蘭縣五結鄉衛生所  宜蘭縣  五結鄉      AstraZeneca  2334090016    宜蘭縣五結鄉五結路2段337號
# 3            吉祥診所  宜蘭縣  五結鄉      AstraZeneca  3534091189  宜蘭縣五結鄉五結中路2段23之1號
# 4            宏安診所  宜蘭縣  五結鄉      AstraZeneca  3534091214    宜蘭縣五結鄉中正路1段168號
# ...           ...  ...  ...              ...         ...                ...
# 14902  尤憲明內科小兒科診所  臺東縣  臺東市  BioNTech(5-11歲)  3546012072    臺東縣臺東市中華路1段396號
# 14903   李旺駿耳鼻喉科診所  臺東縣  臺東市  BioNTech(5-11歲)  3546012358    臺東縣臺東市中華路一段317號
# 14904    小太陽小兒科診所  臺東縣  臺東市  BioNTech(5-11歲)  3546012376      臺東縣臺東市光明路124號
# 14905   臺東縣關山鎮衛生所  臺東縣  關山鎮  BioNTech(5-11歲)  2346030011    臺東縣關山鎮中福里中華路78號
# 14906   台東縣蘭嶼鄉衛生所  臺東縣  蘭嶼鄉  BioNTech(5-11歲)  2346160014       臺東縣蘭嶼鄉紅頭村36號
#
#                電話 Unnamed: 7
# 0      03-9892573        NaN
# 1      03-9801175        NaN
# 2      03-9501564        NaN
# 3      03-9604853        NaN
# 4      03-9576893        NaN
# ...           ...        ...
# 14902  089-323306        NaN
# 14903  089-310568        NaN
# 14904  089-349106        NaN
# 14905  089-811042        NaN
# 14906  089-732575        NaN
#
# [14907 rows x 8 columns]

# %%
#查詢資料和清理資料
#重新安排整理資料

print(df_all.dtypes)
print(df_all.shape)
# Out:
# 院所名稱          object
# 縣市            object
# 鄉鎮            object
# 疫苗種類名稱        object
# 醫事機構代碼        object
# 地址            object
# 電話            object
# Unnamed: 7    object
# dtype: object
# (14907, 8)
# 119256

# %%
#search,所有AZ的院所名稱
az_series =  df_all["疫苗種類名稱"] == "AstraZeneca"
az_sites = df_all[az_series]
az_sites
# Out:
#              院所名稱   縣市   鄉鎮       疫苗種類名稱      醫事機構代碼                   地址  \
# 0            仁佑診所  宜蘭縣  三星鄉  AstraZeneca  3534101064       宜蘭縣三星鄉三星路5段67號
# 1       宜蘭縣大同鄉衛生所  宜蘭縣  大同鄉  AstraZeneca  2334110013       宜蘭縣大同鄉崙埤村朝陽40號
# 2       宜蘭縣五結鄉衛生所  宜蘭縣  五結鄉  AstraZeneca  2334090016      宜蘭縣五結鄉五結路2段337號
# 3            吉祥診所  宜蘭縣  五結鄉  AstraZeneca  3534091189    宜蘭縣五結鄉五結中路2段23之1號
# 4            宏安診所  宜蘭縣  五結鄉  AstraZeneca  3534091214      宜蘭縣五結鄉中正路1段168號
# ...           ...  ...  ...          ...         ...                  ...
# 2184    江明儒耳鼻喉科診所  澎湖縣  馬公市  AstraZeneca  3544011639         澎湖縣馬公市大勇街65號
# 2185    澎湖縣望安鄉衛生所  澎湖縣  望安鄉  AstraZeneca  2344050015       澎湖縣望安鄉西安村36－7號
# 2186  澎湖縣望安鄉將軍衛生所  澎湖縣  望安鄉  AstraZeneca  2344050024  澎湖縣望安鄉將軍村12鄰將軍澳1之3號
# 2187    澎湖縣湖西鄉衛生所  澎湖縣  湖西鄉  AstraZeneca  2344020017      澎湖縣湖西鄉湖西村151－1號
# 2188    育安家庭醫學科診所  澎湖縣  湖西鄉  AstraZeneca  3544021046    澎湖縣湖西鄉龍門村良文港23－3號
#
#               電話 Unnamed: 7
# 0     03-9892573        NaN
# 1     03-9801175        NaN
# 2     03-9501564        NaN
# 3     03-9604853        NaN
# 4     03-9576893        NaN
# ...          ...        ...
# 2184  06-9276768        NaN
# 2185  06-9991036        NaN
# 2186  06-9902066        NaN
# 2187  06-9921271        NaN
# 2188  06-9923379        NaN
#
# [2189 rows x 8 columns]

# %%
df_all.query("疫苗種類名稱 == 'AstraZeneca'")
# Out:
#              院所名稱   縣市   鄉鎮       疫苗種類名稱      醫事機構代碼                   地址  \
# 0            仁佑診所  宜蘭縣  三星鄉  AstraZeneca  3534101064       宜蘭縣三星鄉三星路5段67號
# 1       宜蘭縣大同鄉衛生所  宜蘭縣  大同鄉  AstraZeneca  2334110013       宜蘭縣大同鄉崙埤村朝陽40號
# 2       宜蘭縣五結鄉衛生所  宜蘭縣  五結鄉  AstraZeneca  2334090016      宜蘭縣五結鄉五結路2段337號
# 3            吉祥診所  宜蘭縣  五結鄉  AstraZeneca  3534091189    宜蘭縣五結鄉五結中路2段23之1號
# 4            宏安診所  宜蘭縣  五結鄉  AstraZeneca  3534091214      宜蘭縣五結鄉中正路1段168號
# ...           ...  ...  ...          ...         ...                  ...
# 2184    江明儒耳鼻喉科診所  澎湖縣  馬公市  AstraZeneca  3544011639         澎湖縣馬公市大勇街65號
# 2185    澎湖縣望安鄉衛生所  澎湖縣  望安鄉  AstraZeneca  2344050015       澎湖縣望安鄉西安村36－7號
# 2186  澎湖縣望安鄉將軍衛生所  澎湖縣  望安鄉  AstraZeneca  2344050024  澎湖縣望安鄉將軍村12鄰將軍澳1之3號
# 2187    澎湖縣湖西鄉衛生所  澎湖縣  湖西鄉  AstraZeneca  2344020017      澎湖縣湖西鄉湖西村151－1號
# 2188    育安家庭醫學科診所  澎湖縣  湖西鄉  AstraZeneca  3544021046    澎湖縣湖西鄉龍門村良文港23－3號
#
#               電話 Unnamed: 7
# 0     03-9892573        NaN
# 1     03-9801175        NaN
# 2     03-9501564        NaN
# 3     03-9604853        NaN
# 4     03-9576893        NaN
# ...          ...        ...
# 2184  06-9276768        NaN
# 2185  06-9991036        NaN
# 2186  06-9902066        NaN
# 2187  06-9921271        NaN
# 2188  06-9923379        NaN
#
# [2189 rows x 8 columns]
