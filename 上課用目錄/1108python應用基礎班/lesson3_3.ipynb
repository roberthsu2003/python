# %%
import csv
file = open('all_students.csv',mode='r',encoding="utf-8")
csv_reader = csv.reader(file)
students = list(csv_reader)
students
# Out:
# [['姓名', '國文', '英文', '數學', '社會', '自然'],
#  ['stu1', '88', '58', '98', '73', '89'],
#  ['stu2', '89', '97', '69', '69', '56'],
#  ['stu3', '89', '87', '69', '79', '83'],
#  ['stu4', '93', '57', '84', '89', '54'],
#  ['stu5', '81', '55', '86', '78', '70'],
#  ['stu6', '90', '71', '70', '72', '60'],
#  ['stu7', '93', '93', '73', '91', '57'],
#  ['stu8', '82', '89', '81', '99', '55'],
#  ['stu9', '78', '73', '59', '60', '92'],
#  ['stu10', '64', '53', '62', '92', '58'],
#  ['stu11', '100', '70', '67', '59', '79'],
#  ['stu12', '76', '68', '69', '59', '90'],
#  ['stu13', '85', '57', '71', '77', '89'],
#  ['stu14', '51', '89', '62', '74', '60'],
#  ['stu15', '58', '52', '71', '70', '73'],
#  ['stu16', '77', '66', '91', '85', '51'],
#  ['stu17', '92', '76', '52', '80', '50'],
#  ['stu18', '59', '93', '98', '58', '62'],
#  ['stu19', '82', '82', '79', '84', '71'],
#  ['stu20', '92', '50', '68', '84', '80'],
#  ['stu21', '79', '73', '93', '67', '79'],
# ...
