# %%
#使用2維的list
#50個學生,每個學生的分數
import random
students = []
for j in range(50):
    scores = []
    for i in range(5):
        scores.append(random.randint(50,100))
    students.append(scores)

students
# Out:
# [[94, 62, 59, 56, 88],
#  [95, 53, 50, 91, 73],
#  [93, 52, 64, 72, 75],
#  [58, 85, 59, 73, 98],
#  [78, 62, 65, 69, 90],
#  [95, 95, 51, 75, 55],
#  [60, 60, 94, 64, 73],
#  [91, 88, 100, 57, 78],
#  [86, 59, 72, 52, 63],
#  [67, 52, 80, 61, 76],
#  [90, 89, 84, 84, 50],
#  [82, 98, 68, 90, 89],
#  [98, 100, 72, 66, 78],
#  [59, 88, 75, 86, 59],
#  [61, 85, 100, 82, 73],
#  [76, 99, 56, 92, 70],
#  [83, 78, 100, 92, 96],
#  [72, 74, 52, 90, 50],
#  [87, 65, 72, 92, 50],
#  [97, 94, 95, 83, 61],
#  [86, 88, 97, 58, 95],
#  [99, 73, 86, 56, 98],
#  [95, 72, 60, 64, 78],
#  [99, 100, 91, 89, 66],
#  [62, 92, 57, 52, 92],
#  [63, 87, 97, 85, 61],
#  [80, 96, 52, 60, 57],
#  [51, 69, 70, 90, 95],
#  [88, 64, 50, 95, 78],
#  [53, 68, 76, 57, 58],
#  [55, 71, 81, 56, 50],
#  [98, 79, 66, 75, 81],
#  [67, 67, 94, 80, 71],
#  [76, 96, 60, 81, 80],
#  [89, 97, 81, 58, 99],
#  [61, 55, 85, 90, 58],
#  [52, 86, 89, 67, 61],
#  [82, 74, 68, 77, 58],
#  [69, 100, 78, 83, 98],
# ...
