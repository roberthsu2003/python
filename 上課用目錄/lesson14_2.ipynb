# %%
import matplotlib.pyplot as plt
student1 = {'chinese':78, 'english':80, 'math': 92, 'history': 75, 'discover':85}
subjects = list(student1.keys())
s1_value = list(student1.values())

student2 = {'chinese':92, 'english':60, 'math': 85, 'history': 62, 'discover':73}
s2_value = list(student2.values())

figure = plt.figure(figsize=(8,5))
axes = figure.add_subplot(1,1,1)
axes.plot(subjects,s1_value,'b-.o')
axes.plot(subjects,s2_value,'r-.o')
print(axes.get_xticks())
print(axes.get_xticklabels())
plt.show()
# Out:
# [0, 1, 2, 3, 4]
# [Text(0, 0, 'chinese'), Text(1, 0, 'english'), Text(2, 0, 'math'), Text(3, 0, 'history'), Text(4, 0, 'discover')]

# %%
import matplotlib.pyplot as plt
student1 = {'chinese':78, 'english':80, 'math': 92, 'history': 75, 'discover':85}
subjects = list(student1.keys())
s1_value = list(student1.values())

student2 = {'chinese':92, 'english':60, 'math': 85, 'history': 62, 'discover':73}
s2_value = list(student2.values())

figure = plt.figure(figsize=(8,5))
axes1 = figure.add_subplot(2,1,1)
axes1.plot(subjects,s1_value,'b-.o')
axes1.plot(subjects,s2_value,'r-.o')
axes1.grid(axis='y')

axes2 = figure.add_subplot(2,1,2)
axes2.plot(subjects,s1_value,'b-.o')
axes2.plot(subjects,s2_value,'r-.o')
axes2.grid(axis='y')
xmin, xmax, ymin, ymax = axes2.axis()
axes2.axis(xmin=1.5,xmax=2.5,ymin=ymin,ymax=ymax+10)

plt.show()

# %%
import random
celsius = []
for _ in range(30):
    celsius.append(random.uniform(28.5, 35.2))
print(celsius)
# Out:
# [30.095510219675557, 32.6696033120382, 30.7599135677535, 33.15033553714679, 31.670393426194785, 31.52394336764045, 32.28672090028512, 28.788850400447863, 32.418049300604864, 32.03787198495802, 35.01549303784659, 35.19989715898867, 34.31680867434329, 28.687773996842605, 32.786268576639465, 29.91026920490588, 28.506329201664293, 31.64431021600018, 30.023308352279564, 32.22364516004472, 34.262774653302465, 33.96637531123936, 30.68532204408953, 29.602160589912533, 30.916506960926437, 32.580399970460945, 32.509695549271484, 31.48859897325023, 30.039461798235095, 28.50165175698901]
