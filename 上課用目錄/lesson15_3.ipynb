# %%
#使用codespace 要安裝中文字型
#install 要加-y
#命令列:sudo apt-get update -y
#命令列:sudo apt-get install -y fonts-wqy-zenhei
#說明網址:https://askubuntu.com/questions/490829/how-can-i-install-chinese-fonts-on-kubuntu-14-04
#字型位置:/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}
#window電腦
#font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)

#mac電腦
#font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)

#codespace
font = FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=8)

subjects = list(student1.keys())
value1 = list(student1.values())

figure = plt.figure()
axes = figure.add_subplot(1,1,1)
axes.plot(subjects,value1,'m-.o')
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 22283 (\N{CJK UNIFIED IDEOGRAPH-570B}) missing from current font.
#   func(*args, **kwargs)
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 25991 (\N{CJK UNIFIED IDEOGRAPH-6587}) missing from current font.
#   func(*args, **kwargs)
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 33521 (\N{CJK UNIFIED IDEOGRAPH-82F1}) missing from current font.
#   func(*args, **kwargs)
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 25976 (\N{CJK UNIFIED IDEOGRAPH-6578}) missing from current font.
#   func(*args, **kwargs)
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 23416 (\N{CJK UNIFIED IDEOGRAPH-5B78}) missing from current font.
#   func(*args, **kwargs)
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 27511 (\N{CJK UNIFIED IDEOGRAPH-6B77}) missing from current font.
#   func(*args, **kwargs)
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 21490 (\N{CJK UNIFIED IDEOGRAPH-53F2}) missing from current font.
#   func(*args, **kwargs)
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 25506 (\N{CJK UNIFIED IDEOGRAPH-63A2}) missing from current font.
#   func(*args, **kwargs)
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/events.py:93: UserWarning: Glyph 32034 (\N{CJK UNIFIED IDEOGRAPH-7D22}) missing from current font.
#   func(*args, **kwargs)
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22283 (\N{CJK UNIFIED IDEOGRAPH-570B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25991 (\N{CJK UNIFIED IDEOGRAPH-6587}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 33521 (\N{CJK UNIFIED IDEOGRAPH-82F1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25976 (\N{CJK UNIFIED IDEOGRAPH-6578}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 23416 (\N{CJK UNIFIED IDEOGRAPH-5B78}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 27511 (\N{CJK UNIFIED IDEOGRAPH-6B77}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21490 (\N{CJK UNIFIED IDEOGRAPH-53F2}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25506 (\N{CJK UNIFIED IDEOGRAPH-63A2}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/vscode/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 32034 (\N{CJK UNIFIED IDEOGRAPH-7D22}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
