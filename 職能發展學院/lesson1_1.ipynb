# %%
print("hello! World!")
# Out:
# hello! World!

# %%
import requests

urlPath = "https://tw.news.yahoo.com/%E9%B4%BB%E6%B5%B7%E7%A7%91%E6%8A%80%E6%97%A5%E4%BB%8A%E7%99%BB%E5%A0%B4-%E4%B8%89%E6%AC%BE%E9%9B%BB%E5%8B%95%E8%BB%8A%E4%BA%AE%E7%9B%B8-013815207.html"
response=requests.get(urlPath)
response.text
# Out:
# '<!doctype html><html id=atomic class="Fz(62.5%) Pos(r)   desktop bktnews-TW-zh-Hant-TW-def ua-undefined ua-undefined" lang=zh-Hant-TW><head><script>\n        window.performance.mark(\'PageStart\');\n        document.documentElement.className += \' JsEnabled jsenabled\';\n        /**\n        * Empty darlaOnready method, to avoid JS error.\n        * This can happen when Async Darla JS file is loaded earlier than Darla Proxy JS.\n        * This method will be overridden by Darla Proxy\n        */\n        window.darlaOnready = function() {};\n        </script><title>【Live】鴻海科技日今登場！三款電動車亮相</title><meta http-equiv=content-type content="text/html; charset=utf-8"><meta http-equiv=x-dns-prefetch-control content=on><meta http-equiv=X-UA-Compatible content=chrome=1><meta name="oath:guce:consent-host" content="guce.yahoo.com"><meta name="news_keywords" content="鴻海, 電動車, 鴻華先進, 年度盛事" /><meta name="twitter:title" content="&#x3010;Live&#x3011;&#x9D3B;&#x6D77;&#x79D1;&#x6280;&#x65E5;&#x4ECA;&#x76
# ...
