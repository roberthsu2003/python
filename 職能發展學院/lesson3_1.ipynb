# %%
import requests

res = requests.get('https://flask-robert.herokuapp.com/youbike')

# %%
print(res.url)
print(res.encoding)
# Out:
# https://api.github.com/events
# utf-8

# %%
content = res.text
print(type(content))
content
# Out:
# <class 'str'>
# ...
