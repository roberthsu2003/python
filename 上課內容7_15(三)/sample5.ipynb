# %%
#請輸出偶數
i = 0
while i<10:
    if i % 2 == 0:
        print(i)
    i += 1
print("程式結束")
# Out:
# 0
# 2
# 4
# 6
# 8
# 程式結束

# %%
#請輸出奇數
for i in range(10):
    if i % 2 == 1:
        print(i)
print("程式結束")
# Out:
# 1
# 3
# 5
# 7
# 9
# 程式結束
