# %%
openedx = 100 #這是建立一個變數
openedx #這是輸出一個變數內容
# Out:
# 100

# %%
#這裏是一個儲存格
a = 7
print("現在a的資料型別是",type(a))

b = 7.0
print("現在b的資料型別是",type(b))

c = '7.0'
print("現在c的資料型別是",type(c))

d = True
print("現在d的資料型別是",type(d))
# Out:
# 現在a的資料型別是 <class 'int'>
# 現在b的資料型別是 <class 'float'>
# 現在c的資料型別是 <class 'str'>
# 現在d的資料型別是 <class 'bool'>

# %%
print("Hello World")
print(a)
print("Hello Python", a , '!')
# Out:
# Hello World
# True
# Hello Python True !

# %%
a = 5
print(id(a))

a = 7
print(id(a))
# Out:
# 4528334096
# 4528334160

# %%
5
# Out:
# 5

# %%
0
# Out:
# 0

# %%
05
# Out:
#   File "<ipython-input-23-65e6e002a62d>", line 1
#     05
#      ^
# SyntaxError: invalid token

# %%
5+9
# Out:
# 14

# %%
100-7
# Out:
# 93

# %%
4-10
# Out:
# -6

# %%
4.0 - 10
# Out:
# -6.0

# %%
9/5
# Out:
# 1.8

# %%
9 // 5
# Out:
# 1

# %%
5 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-30-a2b1c63d79f2> in <module>
# ----> 1 5 / 0
#
# ZeroDivisionError: division by zero

# %%
a = 95
a
# Out:
# 95

# %%
b = a - 3
b
a
# Out:
# 95

# %%
a = 95
a = a - 3
a
# Out:
# 92

# %%
a = 95
a -= 3
a
# Out:
# 92

# %%
2 + 3 * 4
# Out:
# 14

# %%
(2+3) * 4
# Out:
# 20

# %%
98.6 + 20
# Out:
# 118.6

# %%
int(98.6) + 20
# Out:
# 118

# %%
'98.6' + 20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-919bd8b0b5e1> in <module>
# ----> 1 '98.6' + 20
#
# TypeError: can only concatenate str (not "int") to str

# %%
float('98.6') + 20
# Out:
# 118.6

# %%
int(float('98.6'))
# Out:
# 98

# %%
2 ** 2
# Out:
# 4

# %%
2 ** 3
# Out:
# 8

# %%
2 ** 100
# Out:
# 1267650600228229401496703205376

# %%
googol = 10 ** 100
googol ** 100
# Out:
# ...

# %%
'snap'
# Out:
# 'snap'

# %%
"snap"
# Out:
# 'snap'

# %%
print("'Nay', said the naysayer.")
# Out:
# 'Nay', said the naysayer.

# %%
print('"Nay", said the naysayer.')
# Out:
# "Nay", said the naysayer.

# %%
"全台持續高溫，部分地區更飆上40度，用電需求直升\
、刷新歷史紀錄，市場關注替代能源問題，加上台積電（2330）大買綠電，\
離岸風電產業開發商大舉招募人才，讓離岸風電題材又熱起來，再搭配技術面落後補漲效應\
，繼上緯投控（3708）後，永冠-KY（1589）16日漲\
逾7％，概念股多收紅，在大盤翻黑之際格外顯目。"
# Out:
# '全台持續高溫，部分地區更飆上40度，用電需求直升、刷新歷史紀錄，市場關注替代能源問題，加上台積電（2330）大買綠電，離岸風電產業開發商大舉招募人才，讓離岸風電題材又熱起來，再搭配技術面落後補漲效應，繼上緯投控（3708）後，永冠-KY（1589）16日漲逾7％，概念股多收紅，在大盤翻黑之際格外顯目。'

# %%
'''全台持續高溫，部分地區更飆上40度，用電需求直升
、刷新歷史紀錄，市場關注替代能源問題，加上台積電（2330）大買綠電，
離岸風電產業開發商大舉招募人才，讓離岸風電題材又熱起來，再搭配技術面落後補漲效應
，繼上緯投控（3708）後，永冠-KY（1589）16日漲
逾7％，概念股多收紅，在大盤翻黑之際格外顯目。'''
# Out:
# '全台持續高溫，部分地區更飆上40度，用電需求直升\n、刷新歷史紀錄，市場關注替代能源問題，加上台積電（2330）大買綠電，\n離岸風電產業開發商大舉招募人才，讓離岸風電題材又熱起來，再搭配技術面落後補漲效應\n，繼上緯投控（3708）後，永冠-KY（1589）16日漲\n逾7％，概念股多收紅，在大盤翻黑之際格外顯目。'

# %%
"""全台持續高溫，部分地區更飆上40度，用電需求直升
、刷新歷史紀錄，市場關注替代能源問題，加上台積電（2330）大買綠電，
離岸風電產業開發商大舉招募人才，讓離岸風電題材又熱起來，再搭配技術面落後補漲效應
，繼上緯投控（3708）後，永冠-KY（1589）16日漲
逾7％，概念股多收紅，在大盤翻黑之際格外顯目。"""
# Out:
# '全台持續高溫，部分地區更飆上40度，用電需求直升\n、刷新歷史紀錄，市場關注替代能源問題，加上台積電（2330）大買綠電，\n離岸風電產業開發商大舉招募人才，讓離岸風電題材又熱起來，再搭配技術面落後補漲效應\n，繼上緯投控（3708）後，永冠-KY（1589）16日漲\n逾7％，概念股多收紅，在大盤翻黑之際格外顯目。'
